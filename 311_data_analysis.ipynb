# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('drive/Data in the Wild/Final Project/ds-final-project/data/311_Service_Requests_from_2010_to_Present.csv')

# %%
df.describe()
# Out:
#          Unique Key  Location Type  Incident Zip  Intersection Street 1  \
# count  1.662900e+04            0.0  16439.000000                    0.0
# mean   2.897543e+07            NaN  10730.741651                    NaN
# std    7.647884e+06            NaN    552.512494                    NaN
# min    1.563632e+07            NaN  10001.000000                    NaN
# 25%    2.262002e+07            NaN  10040.000000                    NaN
# 50%    2.777702e+07            NaN  10472.000000                    NaN
# 75%    3.525643e+07            NaN  11226.000000                    NaN
# max    4.258350e+07            NaN  11697.000000                    NaN
#
#        Intersection Street 2  Landmark  Facility Type  Due Date           BBL  \
# count                    0.0       0.0            0.0       0.0  1.635800e+04
# mean                     NaN       NaN            NaN       NaN  2.476391e+09
# std                      NaN       NaN            NaN       NaN  1.143599e+09
# min                      NaN       NaN            NaN       NaN  0.000000e+00
# 25%                      NaN       NaN            NaN       NaN  1.021613e+09
# 50%                      NaN       NaN            NaN       NaN  2.058946e+09
# 75%                      NaN       NaN            NaN       NaN  3.065618e+09
# max                      NaN       NaN            NaN       NaN  5.080120e+09
#
#        X Coordinate (State Plane)  Y Coordinate (State Plane)  Vehicle Type  \
# count                1.643900e+04                16439.000000           0.0
# mean                 1.005966e+06               210894.226595           NaN
# std                  1.864442e+04                30962.313064           NaN
# min                  9.155320e+05               122368.000000           NaN
# 25%                  9.951650e+05               185876.000000           NaN
# 50%                  1.003801e+06               210434.000000           NaN
# 75%                  1.015281e+06               239723.000000           NaN
# max                  1.067065e+06               271133.000000           NaN
#
#        Taxi Company Borough  Taxi Pick Up Location  Bridge Highway Name  \
# count                   0.0                    0.0                  0.0
# mean                    NaN                    NaN                  NaN
# std                     NaN                    NaN                  NaN
# min                     NaN                    NaN                  NaN
# 25%                     NaN                    NaN                  NaN
# 50%                     NaN                    NaN                  NaN
# 75%                     NaN                    NaN                  NaN
# max                     NaN                    NaN                  NaN
#
#        Bridge Highway Direction  Road Ramp  Bridge Highway Segment  \
# count                       0.0        0.0                     0.0
# mean                        NaN        NaN                     NaN
# std                         NaN        NaN                     NaN
# min                         NaN        NaN                     NaN
# 25%                         NaN        NaN                     NaN
# 50%                         NaN        NaN                     NaN
# 75%                         NaN        NaN                     NaN
# max                         NaN        NaN                     NaN
#
#            Latitude     Longitude
# count  16439.000000  16439.000000
# mean      40.745486    -73.921607
# std        0.084985      0.067259
# min       40.502294    -74.247113
# 25%       40.676811    -73.960674
# 50%       40.744264    -73.929413
# 75%       40.824595    -73.887906
# max       40.910825    -73.701136

# %%
print(df.shape)
# Out:
# (16629, 41)

# %%
print(df.iloc[0])
# Out:
# Unique Key                                                                 31226291
# Created Date                                                 08/03/2015 08:43:41 AM
# Closed Date                                                  08/26/2015 12:00:00 AM
# Agency                                                                          DOB
# Agency Name                                                 Department of Buildings
# Complaint Type                                                              Boilers
# Descriptor                                 Boiler - Defective/Inoperative/No Permit
# Location Type                                                                   NaN
# Incident Zip                                                                  10456
# Incident Address                                               540 EAST  169 STREET
# Street Name                                                        EAST  169 STREET
# Cross Street 1                                                                  NaN
# Cross Street 2                                                                  NaN
# Intersection Street 1                                                           NaN
# Intersection Street 2                                                           NaN
# Address Type                                                                ADDRESS
# City                                                                          BRONX
# Landmark                                                                        NaN
# Facility Type                                                                   NaN
# Status                                                                       Closed
# Due Date                                                                        NaN
# Resolution Description            The Department of Buildings investigated this ...
# Resolution Action Updated Date                               08/26/2015 12:00:00 AM
# Community Board                                                            03 BRONX
# BBL                                                                      2.0261e+09
# Borough                                                                       BRONX
# X Coordinate (State Plane)                                              1.01071e+06
# Y Coordinate (State Plane)                                                   242594
# Open Data Channel Type                                                      UNKNOWN
# Park Facility Name                                                      Unspecified
# Park Borough                                                                  BRONX
# Vehicle Type                                                                    NaN
# Taxi Company Borough                                                            NaN
# Taxi Pick Up Location                                                           NaN
# Bridge Highway Name                                                             NaN
# Bridge Highway Direction                                                        NaN
# Road Ramp                                                                       NaN
# Bridge Highway Segment                                                          NaN
# Latitude                                                                    40.8325
# Longitude                                                                  -73.9044
# Location                                   (40.832500257709135, -73.90439406423718)
# Name: 0, dtype: object

# %%
import matplotlib.pyplot as plt
df['OATH_Summons'] = df['Resolution Description'].str.contains('OATH')
df['OATH_Summons'].value_counts().plot(kind='bar',title='OATH Summons Issued')

# %%
print(df.columns)
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location', 'OATH_Summons'],
#       dtype='object')

# %%
now_df = pd.read_csv('drive/Data in the Wild/Final Project/ds-final-project/data/DOB_NOW_Boiler_Safety.csv')

# %%
print(now_df.columns)
# Out:
# Index(['version https://git-lfs.github.com/spec/v1'], dtype='object')
