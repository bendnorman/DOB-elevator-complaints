# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Data Cleaning

# %%
all_complaints = pd.read_csv('data/DOB_Complaints_Received.csv')
print(list(all_complaints))
print(len(all_complaints))
# Out:
# /Users/apple/.virtualenvs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (4,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['Complaint Number', 'Status', 'Date Entered', 'House Number', 'ZIP Code', 'House Street', 'BIN', 'Community Board', 'Special District', 'Complaint Category', 'Unit', 'Disposition Date', 'Disposition Code', 'Inspection Date', 'DOBRunDate']
# 2299448

# %% [markdown]
# ### Handle types

# %%
all_complaints['Complaint Category'] = all_complaints['Complaint Category'].astype(str)

# %% [markdown]
# ### Filter down to just Boilers

# %%
# complaint_categories = ['58', '56', '82']
complaint_categories = ['58']

boiler_complaints = all_complaints[all_complaints['Complaint Category'].isin(complaint_categories)]

print("Number of total complaints: {}".format(len(all_complaints)))
print("Number of boiler complaints: {}".format(len(boiler_complaints)))

boiler_complaints['Complaint Category'].value_counts()
# Out:
# Number of total complaints: 2299448
# Number of boiler complaints: 29745
# 58    29745
# Name: Complaint Category, dtype: int64

# %%
boiler_complaints['Inspection Date'] = pd.to_datetime(boiler_complaints['Inspection Date'])
boiler_complaints.groupby(boiler_complaints['Inspection Date'].dt.year).count()['BIN'].plot(kind='bar')
# Out:
# /Users/apple/.virtualenvs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ### Remove Duplicates

# %%
boiler_complaints = boiler_complaints.drop_duplicates(subset=['BIN', 'Date Entered'])
print("number of boiler complaints after dropping duplicates: {}".format(len(boiler_complaints)))
# Out:
# number of boiler complaints after dropping duplicates: 27690

# %% [markdown]
# ### Filter down to relevant labels

# %%
# print(boiler_complaints['Disposition Code'].value_counts())
boiler_complaints.groupby('Disposition Code').count()['BIN'].plot('bar', figsize=(20, 6), fontsize=15)

# %% [markdown]
# **Positive**: A8 (ECB Violation Served), A1 (Buildings Violation(s) Served), B1 (Buildings Violation(s) Prepared and Attempt to Serve will be Made)
#
# **Negative**: I2 (No Violation Warranted for Complaint at Time of Inspection), I1 (Complaint Unsubstantiated Based on Department Records),
#
# **Note**: C2 (Inspector Unable to Gain Access – Final Attempt) did not include to assume we could gain access to the building.  It kind of seems like that would be a different classification task

# %%
positive_labels = ['A1', 'A8', 'B1']
negative_labels = ['I1', 'I2']
boiler_complaints = boiler_complaints[boiler_complaints['Disposition Code'].isin(positive_labels + negative_labels)]
print("Number of complaints after filter down to relevant dispoisition codes: {}".format(len(boiler_complaints)))
# Out:
# Number of complaints after filter down to relevant dispoisition codes: 17511

# %% [markdown]
# # Create Labels

# %%
labels = boiler_complaints['Disposition Code'].isin(positive_labels) * 1

# %%
print("Percent of labels that are positive (result in violation): {}".format(sum(labels) / len(labels)))
# Out:
# Percent of labels that are positive (result in violation): 0.5244703329335846

# %% [markdown]
# # Create Features

# %%
features = pd.DataFrame()
features['Violation'] = labels
boiler_complaints['Violation'] = labels
features.head()
# Out:
#       Violation
# 2082          1
# 2083          0
# 2084          1
# 2094          0
# 2883          0

# %%
def violation_ratio_test(column):
    return features.groupby(column)['Violation'].sum() / features.groupby(column).count()['Violation']

# %% [markdown]
# ### Boiler Category / Priority

# %%
boiler_complaints['Complaint Category'].value_counts()
# Out:
# 58    17511
# Name: Complaint Category, dtype: int64

# %%
boiler_complaints['Complaint Category'] = boiler_complaints['Complaint Category'].astype('category')
boiler_complaints['Complaint Category'] = boiler_complaints['Complaint Category'].cat.codes
features['Complaint Category'] = boiler_complaints['Complaint Category']

# %%
violation_ratio_test('Complaint Category')
# Out:
# Complaint Category
# 0    0.52447
# Name: Violation, dtype: float64

# %% [markdown]
# ### Number of previous boiler complaints

# %%
def get_previous_complaints(row):
    # Get all of complaings with same BIN
    # remove complaints with same complaint number
    # get total of violation (could even do violation ratio)
    bin_complaints = boiler_complaints[boiler_complaints['BIN'] == row['BIN']]
    bin_complaints = bin_complaints[boiler_complaints['Complaint Number'] != row['Complaint Number']]
    return len(bin_complaints)

# %%
features['Previous Complaints'] = boiler_complaints.apply(get_previous_complaints, axis=1 )
# Out:
# /Users/apple/.virtualenvs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
features['Previous Complaints'].value_counts()
# Out:
# 0     9114
# 1     3262
# 2     1635
# 3      836
# 4      505
# 5      312
# 6      308
# 7      200
# 9      170
# 8      135
# 10     132
# 13      98
# 40      82
# 14      75
# 73      74
# 22      69
# 66      67
# 12      65
# 11      60
# 51      52
# 16      51
# 19      40
# 36      37
# 17      36
# 26      27
# 25      26
# 21      22
# 20      21
# Name: Previous Complaints, dtype: int64

# %%
violation_ratio_test('Previous Complaints')
# Out:
# Previous Complaints
# 0     0.543120
# 1     0.531576
# 2     0.560245
# 3     0.531100
# 4     0.499010
# 5     0.500000
# 6     0.542208
# 7     0.340000
# 8     0.503704
# 9     0.441176
# 10    0.416667
# 11    0.300000
# 12    0.523077
# 13    0.285714
# 14    0.440000
# 16    0.254902
# 17    0.222222
# 19    0.400000
# 20    0.047619
# 21    0.636364
# 22    0.492754
# 25    0.346154
# 26    0.296296
# 36    0.216216
# 40    0.256098
# 51    0.326923
# 66    0.283582
# 73    0.243243
# Name: Violation, dtype: float64

# %%
# The less previous complaints a building has, the more likely it is the complaint will result in a violation

# %%
# Checking to make sure these aren't duplicate 
boiler_complaints[boiler_complaints['BIN'] == 1015102]
# Out:
#         Complaint Number  Status Date Entered  House Number   ZIP Code  \
# 127622           1134056  CLOSED   12/19/2004  139           10001
# 181203           1190768  CLOSED   04/10/2007  139           10001
#
#                             House Street      BIN Community Board  \
# 127622  WEST   28 STREET                  1015102             105
# 181203  WEST   28 STREET                  1015102             105
#
#        Special District  Complaint Category   Unit Disposition Date  \
# 127622                                    0  BOILR       01/24/2005
# 181203                                    0  BOILR       05/04/2007
#
#        Disposition Code Inspection Date              DOBRunDate  Violation
# 127622               I2      2005-01-18  11/07/2018 12:00:00 AM          0
# 181203               A1      2007-04-27  11/07/2018 12:00:00 AM          1

# %% [markdown]
# ### Number of previous boiler violations
# TODO: might be better for this to come from the DOB Violation dataset?
#
# Make sure current complaint is not included in the number of previous violations! (This would include the label in the features... yikes man)

# %%
def get_previous_violations(row):
    # Get all of complaings with same BIN
    # remove complaints with same complaint number
    # get total of violation (could even do violation ratio)
    bin_complaints = boiler_complaints[boiler_complaints['BIN'] == row['BIN']]
    bin_complaints = bin_complaints[bin_complaints['Violation'] == 1]
    bin_complaints = bin_complaints[boiler_complaints['Complaint Number'] != row['Complaint Number']]
    return len(bin_complaints)

# %%
# # get_previous_violations test
# for row in boiler_complaints.iterrows():
#     num_previous_complaints = get_previous_violations(row[1])
#     print(num_previous_complaints)
# #     break

# %%
features['Previous Violations'] = boiler_complaints.apply(get_previous_violations, axis=1 )
# Out:
# /Users/apple/.virtualenvs/python36/lib/python3.6/site-packages/ipykernel_launcher.py:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   import sys

# %%
features['Previous Violations'].value_counts()
# Out:
# 0     11401
# 1      2899
# 2      1282
# 3       644
# 4       342
# 5       231
# 6       151
# 8       120
# 18       98
# 7        95
# 17       71
# 19       48
# 9        47
# 13       28
# 21       22
# 16       17
# 14       14
# 22        1
# Name: Previous Violations, dtype: int64

# %%
violation_ratio_test('Previous Violations')
# Out:
# Previous Violations
# 0     0.511709
# 1     0.542256
# 2     0.641186
# 3     0.478261
# 4     0.599415
# 5     0.597403
# 6     0.463576
# 7     0.421053
# 8     0.525000
# 9     0.212766
# 13    1.000000
# 14    0.000000
# 16    1.000000
# 17    0.507042
# 18    0.193878
# 19    0.000000
# 21    1.000000
# 22    0.000000
# Name: Violation, dtype: float64

# %% [markdown]
# ### Number of previous boiler violations / complaints ratio

# %%
features['Violation Ratio'] = (features['Previous Violations'] / features['Previous Complaints']).fillna(0)
features.head()
# Out:
#       Violation  Complaint Category  Previous Complaints  Previous Violations  \
# 2082          1                   0                    0                    0
# 2083          0                   0                    3                    2
# 2084          1                   0                    0                    0
# 2094          0                   0                    0                    0
# 2883          0                   0                    1                    1
#
#       Violation Ratio
# 2082         0.000000
# 2083         0.666667
# 2084         0.000000
# 2094         0.000000
# 2883         1.000000

# %%
print(features['Violation Ratio'].value_counts())
violation_ratio_test('Violation Ratio')
# Out:
# 0.000000    11401
# 1.000000     2677
# 0.500000      920
# 0.666667      416
# 0.333333      282
# 0.250000      156
# 0.750000      135
# 0.200000       90
# 0.600000       88
# 0.428571       72
# 0.285714       62
# 0.800000       61
# 0.400000       59
# 0.246575       56
# 0.222222       51
# 0.272727       48
# 0.287879       48
# 0.142857       47
# 0.833333       44
# 0.075000       38
# 0.375000       33
# 0.076923       28
# 0.444444       27
# 0.125000       27
# 0.571429       26
# 0.307692       24
# 0.050000       23
# 0.450000       23
# 0.625000       22
# 0.954545       22
#             ...
# 0.888889       11
# 0.181818       11
# 0.230769       11
# 0.777778       11
# 0.437500       10
# 0.714286        9
# 0.857143        9
# 0.615385        9
# 0.384615        9
# 0.320000        9
# 0.700000        8
# 0.363636        8
# 0.636364        8
# 0.269231        8
# 0.194444        8
# 0.461538        7
# 0.538462        7
# 0.642857        6
# 0.736842        6
# 0.416667        6
# 0.294118        6
# 0.583333        6
# 0.692308        5
# 0.727273        4
# 0.187500        4
# 0.875000        4
# 0.058824        2
# 0.062500        2
# 0.100000        2
# 0.052632        2
# Name: Violation Ratio, Length: 77, dtype: int64
# Violation Ratio
# 0.000000    0.511709
# 0.050000    0.130435
# 0.052632    1.000000
# 0.058824    1.000000
# 0.062500    1.000000
# 0.075000    0.000000
# 0.076923    0.071429
# 0.100000    1.000000
# 0.105263    0.000000
# 0.111111    0.181818
# 0.117647    0.000000
# 0.125000    0.148148
# 0.142857    0.255319
# 0.153846    0.200000
# 0.166667    0.368421
# 0.181818    1.000000
# 0.187500    1.000000
# 0.194444    1.000000
# 0.200000    0.177778
# 0.222222    0.117647
# 0.227273    0.000000
# 0.230769    0.000000
# 0.232877    1.000000
# 0.246575    0.000000
# 0.250000    0.301282
# 0.269231    1.000000
# 0.272727    0.625000
# 0.285714    0.419355
# 0.287879    0.000000
# 0.294118    1.000000
#               ...
# 0.444444    0.555556
# 0.450000    0.000000
# 0.461538    1.000000
# 0.500000    0.545652
# 0.538462    0.000000
# 0.555556    0.285714
# 0.571429    0.538462
# 0.583333    0.000000
# 0.600000    0.409091
# 0.615385    1.000000
# 0.619048    1.000000
# 0.625000    0.818182
# 0.636364    1.000000
# 0.642857    0.000000
# 0.666667    0.706731
# 0.684211    1.000000
# 0.692308    0.000000
# 0.700000    1.000000
# 0.714286    0.666667
# 0.727273    0.000000
# 0.736842    0.000000
# 0.750000    0.548148
# 0.777778    0.727273
# 0.800000    0.655738
# 0.833333    0.545455
# 0.857143    0.777778
# 0.875000    0.000000
# 0.888889    0.818182
# 0.954545    1.000000
# 1.000000    0.655585
# Name: Violation, Length: 77, dtype: float64

# %%
features['ZIP Code'] = boiler_complaints['ZIP Code'].astype('category').cat.codes
features.head()
# Out:
#       Violation  Complaint Category  Previous Complaints  Previous Violations  \
# 2082          1                   0                    0                    0
# 2083          0                   0                    3                    2
# 2084          1                   0                    0                    0
# 2094          0                   0                    0                    0
# 2883          0                   0                    1                    1
#
#       Violation Ratio  ZIP Code
# 2082         0.000000        64
# 2083         0.666667        72
# 2084         0.000000        49
# 2094         0.000000        83
# 2883         1.000000        70

# %%
features['BIN'] = boiler_complaints['BIN'].astype('category').cat.codes
features.head()
# Out:
#       Violation  Complaint Category  Previous Complaints  Previous Violations  \
# 2082          1                   0                    0                    0
# 2083          0                   0                    3                    2
# 2084          1                   0                    0                    0
# 2094          0                   0                    0                    0
# 2883          0                   0                    1                    1
#
#       Violation Ratio  ZIP Code   BIN
# 2082         0.000000        64  1883
# 2083         0.666667        72  2636
# 2084         0.000000        49   108
# 2094         0.000000        83  3228
# 2883         1.000000        70  2405

# %%
boiler_complaints['Date Entered'] = pd.to_datetime(boiler_complaints['Date Entered'])

# %%
features['Day'] = boiler_complaints['Date Entered'].apply(lambda date: date.day)
features.head()
# Out:
#       Violation  Complaint Category  Previous Complaints  Previous Violations  \
# 2082          1                   0                    0                    0
# 2084          1                   0                    0                    0
# 2094          0                   0                    0                    0
# 2883          0                   0                    1                    1
# 4670          0                   0                    0                    0
#
#       Violation Ratio  ZIP Code   BIN  Boiler Make  Pressure Type  Defects  \
# 2082              0.0        64  1883           19              1      1.0
# 2084              0.0        49   108          121              1      1.0
# 2094              0.0        83  3228           40              1      1.0
# 2883              1.0        70  2405           13              1      2.0
# 4670              0.0        83  1441            4              1      5.0
#
#       Month  Day
# 2082      6    8
# 2084      6    8
# 2094      6    8
# 2883      8   11
# 4670      1    9

# %% [markdown]
# # Boiler make

# %%
boiler_inspections = pd.read_csv('data/DOB_NOW_Boiler_Safety.csv')
list(boiler_inspections)
# Out:
# ['Tracking Number',
#  'Boiler ID',
#  'Report Type',
#  'ApplicantFirst Name',
#  'Applicant Last Name',
#  'Applicant License Type',
#  'Applicant License Number',
#  'Owner First Name',
#  'Owner Last Name',
#  'Boiler Make',
#  'Boiler Model',
#  'Pressure Type',
#  'Inspection Type',
#  'Inspection Date',
#  'Defects Exist',
#  'LFF (45 Days)',
#  'LFF (180 Days)',
#  'Filing Fee',
#  'Total Amount Paid',
#  'Report Status',
#  'Bin Number']

# %% [markdown]
# ### Drop nan Boiler makes

# %%
boiler_features = ['Boiler Make', 'Defects Exist', 'Pressure Type']

print(len(boiler_inspections))
boiler_inspections = boiler_inspections.dropna(subset=boiler_features)
print(len(boiler_inspections))
# Out:
# 169583
# 162877

# %%
print("{} types of models".format(len(set(boiler_inspections['Boiler Model']))))
print("{} types of makes".format(len(set(boiler_inspections['Boiler Make']))))
# Out:
# 14798 types of models
# 2247 types of makes

# %% [markdown]
# ### Convert to to datetime

# %%
boiler_inspections['Inspection Date'] = pd.to_datetime(boiler_inspections['Inspection Date'])
boiler_inspections['Defects Exist'] = boiler_inspections['Defects Exist'].map({'Yes': 1, 'No':0})

# %% [markdown]
# ### Clean boiler makes

# %%
from difflib import SequenceMatcher

def similarity(a, b):
#     print(a)
#     print(b)
#     print()
    return SequenceMatcher(None, a, b).ratio()

# %%
print("[similarity()] tests")
print(similarity('LOCH-CERST', 'LOCH-CREST'))
print(similarity('WEIL MCLAIN', 'BEST'))
print(similarity('H B SMITH NEW', 'SMITH    H'))
print()
# create maping of a make to the other spellings
makes = {}

for make in set(boiler_inspections['Boiler Make']):
    # is there something similar in the set of keys? if so put it in the values, if not, create a new key
#     print(f"looking at {make}")
    threshold = 0.6
    found_key = ''
    
    for key in makes.keys():
        sim = similarity(key, make)
        if sim >= threshold:
            found_key = key
            break
        else:
            continue
    
    if found_key != '':
#         print(found_key)
        makes[found_key].append(make)
    else:
        makes[make] = [make]
#     print(makes)
# Out:
# [similarity()] tests
# 0.9
# 0.13333333333333333
# 0.5217391304347826

# %%
print(len(makes.keys()))
# invert the mapping
inverted_makes = {}

for make_key, make_values in makes.items():
    for m in make_values:
        inverted_makes[m] = make_key
        
inverted_makes
# Out:
# 435
# {'SLANTEIN': 'SLANTEIN',
#  'SLANT FIN VIC': 'SLANTEIN',
#  'SLANTFIN SX-1': 'SLANTEIN',
#  'SLANTFI': 'SLANTEIN',
#  'SLNT FIN': 'SLANTEIN',
#  'SLANT FINN': 'SLANTEIN',
#  'SLANT/FIN CAR': 'SLANTEIN',
#  'SLINTFIN': 'SLANTEIN',
#  'NLANT FIN': 'SLANTEIN',
#  'SLANFIN': 'SLANTEIN',
#  'SNANT FIN': 'SLANTEIN',
#  'SLANT FINN GG': 'SLANTEIN',
#  'SLANT-FIN': 'SLANTEIN',
#  'SLANT FN': 'SLANTEIN',
#  'SLANTFIN GGT-': 'SLANTEIN',
#  'SLANT/FI': 'SLANTEIN',
#  'SLANT FIN/HYDRO': 'SLANTEIN',
#  'SLANTFINN': 'SLANTEIN',
#  'SLANT/FINN': 'SLANTEIN',
#  'SLANF FIN': 'SLANTEIN',
#  '8LANTEIN': 'SLANTEIN',
#  'SLANTFIN': 'SLANTEIN',
#  'SLANT FI': 'SLANTEIN',
#  'SLAN FINT': 'SLANTEIN',
#  'SLANT FIN GX': 'SLANTEIN',
#  'SLANTF FIN': 'SLANTEIN',
#  'SLANT  FIN': 'SLANTEIN',
#  'SLANT FINM': 'SLANTEIN',
#  'SLAN FIN': 'SLANTEIN',
#  'SLANTFINN GXH': 'SLANTEIN',
#  'SLANTFIN INTERA': 'SLANTEIN',
#  'SLANT FIN GAL': 'SLANTEIN',
#  'SALNTFIN': 'SLANTEIN',
#  'SLANT': 'SLANTEIN',
#  'SLAINT FIN': 'SLANTEIN',
#  'STATE': 'SLANTEIN',
#  'ATLANTIC': 'SLANTEIN',
#  'SLANTFIN GALAXY': 'SLANTEIN',
#  'SLANT/ FIN': 'SLANTEIN',
#  'STANT FIN': 'SLANTEIN',
#  'SLANT FIN 90R': 'SLANTEIN',
#  'SLANT FIN LIB': 'SLANTEIN',
#  'SLNAT FIN': 'SLANTEIN',
#  'SLANT FIN LD-60': 'SLANTEIN',
#  'SLANT/FIN': 'SLANTEIN',
#  'SLANT FIN': 'SLANTEIN',
#  'SLANT FINNGG300': 'SLANTEIN',
#  'SLAT FIN': 'SLANTEIN',
#  'SLAINTEIN': 'SLANTEIN',
#  'SLAINT FIN..G': 'SLANTEIN',
#  'SLANT FIN GGT': 'SLANTEIN',
#  'SALNT FIN': 'SLANTEIN',
#  'LAARS PNCH-1750': 'LAARS PNCH-1750',
#  'LAARS PNCH 75': 'LAARS PNCH-1750',
#  'LAARS NB#190092': 'LAARS PNCH-1750',
#  'LAARS PNCH0750': 'LAARS PNCH-1750',
#  'LAARS PNCH050': 'LAARS PNCH-1750',
#  'LAARS PW-025': 'LAARS PNCH-1750',
#  'LAARS PENN.': 'LAARS PNCH-1750',
#  'LAARS PNCH500': 'LAARS PNCH-1750',
#  'LAARS RHHH-20': 'LAARS PNCH-1750',
#  'LAARS PNCH 1250': 'LAARS PNCH-1750',
#  'LAARS RHHH-2000': 'LAARS PNCH-1750',
#  'LAARS PNCH-75': 'LAARS PNCH-1750',
#  'LAARS JVT-160': 'LAARS PNCH-1750',
#  'LAARS PNCH 0750': 'LAARS PNCH-1750',
#  'LAARS/RHCH1600': 'LAARS PNCH-1750',
#  'LAARS NT': 'LAARS PNCH-1750',
#  'LAARS NTH 500': 'LAARS PNCH-1750',
#  'LAARS PW0250V': 'LAARS PNCH-1750',
#  'LAARS PNCH': 'LAARS PNCH-1750',
#  'LAARS MT2-500': 'LAARS PNCH-1750',
#  'LAARS PNC': 'LAARS PNCH-1750',
#  'LAARS PEN.': 'LAARS PNCH-1750',
#  'LAARS RHHH-2400': 'LAARS PNCH-1750',
#  'LAAR PNCH 1250': 'LAARS PNCH-1750',
#  'LAARS PNCH2000': 'LAARS PNCH-1750',
#  'TELEDYNE LAARS PNCH0': 'LAARS PNCH-1750',
#  'LAARS PNCH 1500': 'LAARS PNCH-1750',
#  'LAARS PNCH 05': 'LAARS PNCH-1750',
#  'LAARS PNCH-0750': 'LAARS PNCH-1750',
#  'LAARS RHHH160': 'LAARS PNCH-1750',
#  'LAARS NTH-080': 'LAARS PNCH-1750',
#  'LAARS PNCH100': 'LAARS PNCH-1750',
#  'LAARS PNCH0500': 'LAARS PNCH-1750',
#  'LAARS PW 1687': 'LAARS PNCH-1750',
#  'LAARS PW1825': 'LAARS PNCH-1750',
#  'LAARS NB#190094': 'LAARS PNCH-1750',
#  'LAARS PNCH1500': 'LAARS PNCH-1750',
#  'LAARS PNCH750': 'LAARS PNCH-1750',
#  'LAARS PNCH-750': 'LAARS PNCH-1750',
#  'AMER.RAD': 'AMER.RAD',
#  'AMERICAN.STAND': 'AMER.RAD',
#  'AMER.EXBROOK': 'AMER.RAD',
#  'AMERIC RAD': 'AMER.RAD',
#  'AMERRADIATOR': 'AMER.RAD',
#  'AMERCSTD': 'AMER.RAD',
#  'AMERICAN RADI': 'AMER.RAD',
#  'AMER. RADIATOR': 'AMER.RAD',
#  'AMERICASTD': 'AMER.RAD',
#  'AMERSTD': 'AMER.RAD',
#  'AMERICANRAD': 'AMER.RAD',
#  'AMERICAN RAD': 'AMER.RAD',
#  'AMER. RADIATO': 'AMER.RAD',
#  'AMER STAD': 'AMER.RAD',
#  'AMER.STAND': 'AMER.RAD',
#  'AMERICAN STD': 'AMER.RAD',
#  'AMER.RADIATOR': 'AMER.RAD',
#  'AMER.STD': 'AMER.RAD',
#  'AMER RAD': 'AMER.RAD',
#  'AMER. STD': 'AMER.RAD',
#  'AMERCAN RAD': 'AMER.RAD',
#  'AMER.STANDARD': 'AMER.RAD',
#  'AMERICRAD': 'AMER.RAD',
#  'AMER STD': 'AMER.RAD',
#  'AMERICA': 'AMER.RAD',
#  'AMER STAND': 'AMER.RAD',
#  'AM RAD': 'AMER.RAD',
#  'AMERSTAND': 'AMER.RAD',
#  'AMERICAN': 'AMER.RAD',
#  'AMER RADIATOR': 'AMER.RAD',
#  'AMERI. RAD': 'AMER.RAD',
#  'SUSSMANMB6L': 'SUSSMANMB6L',
#  'SUSSMAN': 'SUSSMANMB6L',
#  'SUSSMANMB-6L': 'SUSSMANMB6L',
#  'SUSSMANIMBA6': 'SUSSMANMB6L',
#  'SUSMAN': 'SUSSMANMB6L',
#  'SUSSMAN ELETR': 'SUSSMANMB6L',
#  'AL EASTMON': 'AL EASTMON',
#  'ALSTOM': 'AL EASTMON',
#  'EASTMOND-FEDE': 'AL EASTMON',
#  'A.L. EASTMOND': 'AL EASTMON',
#  'A.L.EASTMOND': 'AL EASTMON',
#  'EASMOND': 'AL EASTMON',
#  'EASTMOND ESP-': 'AL EASTMON',
#  'FEDERAL EASTMOND': 'AL EASTMON',
#  'ALEASTMOND & SONS': 'AL EASTMON',
#  'AL EASTMOND & SONS': 'AL EASTMON',
#  'EASTCO': 'AL EASTMON',
#  'EASTOMOND': 'AL EASTMON',
#  'FEDERALEASTMO': 'AL EASTMON',
#  'AL EASTMOND &': 'AL EASTMON',
#  'A. L. EASTMAN': 'AL EASTMON',
#  'EASTMOND CARL': 'AL EASTMON',
#  'M* EASMOND NB': 'AL EASTMON',
#  'A & L EASTMOND': 'AL EASTMON',
#  'EASTMOND': 'AL EASTMON',
#  'EASTMAN': 'AL EASTMON',
#  'NEW EASTMOND': 'AL EASTMON',
#  'FEDERAL/EASTMOND': 'AL EASTMON',
#  'FEDERAL-EASTM': 'AL EASTMON',
#  'EASTMONT': 'AL EASTMON',
#  'M* EASTMOND N': 'AL EASTMON',
#  'EASTMON': 'AL EASTMON',
#  'FEDERAL/EASTMAN': 'AL EASTMON',
#  'EASTMUND': 'AL EASTMON',
#  'DUNKIRK PVSB': 'DUNKIRK PVSB',
#  'DUNNKIRK': 'DUNKIRK PVSB',
#  'DUNKRIK': 'DUNKIRK PVSB',
#  'DUNKIRK PSB71': 'DUNKIRK PVSB',
#  'DUNKIRKN STD': 'DUNKIRK PVSB',
#  'DUNKIRK RADIA': 'DUNKIRK PVSB',
#  'DUNKIRKRA': 'DUNKIRK PVSB',
#  'DUNKIRK PSB91': 'DUNKIRK PVSB',
#  'DUNKIRKLAIN': 'DUNKIRK PVSB',
#  'DUNKIRK RAD C': 'DUNKIRK PVSB',
#  'DUNKIRK RA': 'DUNKIRK PVSB',
#  'DUNKINK': 'DUNKIRK PVSB',
#  'DUNDIRK': 'DUNKIRK PVSB',
#  'DURKIRK': 'DUNKIRK PVSB',
#  'DUNKIRK RAD': 'DUNKIRK PVSB',
#  'DUNKIRK DXL10': 'DUNKIRK PVSB',
#  'DUNKIRK': 'DUNKIRK PVSB',
#  'CI DUNKIRK': 'DUNKIRK PVSB',
#  'U.S.RADIATOR': 'U.S.RADIATOR',
#  'US RADIATOR': 'U.S.RADIATOR',
#  'U.S.CAPITOL': 'U.S.RADIATOR',
#  'US. RAD': 'U.S.RADIATOR',
#  'U.S.RADITOR': 'U.S.RADIATOR',
#  'U. S. RADIATO': 'U.S.RADIATOR',
#  'US RADIATO': 'U.S.RADIATOR',
#  'U.S. RADIATOR': 'U.S.RADIATOR',
#  'U.S. CAPITOL': 'U.S.RADIATOR',
#  'USRADIATOR': 'U.S.RADIATOR',
#  'NATIONAL US RADIATOR': 'U.S.RADIATOR',
#  'US RADIATION': 'U.S.RADIATOR',
#  'RADIATOR US': 'U.S.RADIATOR',
#  'PRESLESS': 'PRESLESS',
#  'PEERLESS JOT': 'PRESLESS',
#  'PROGRESS': 'PRESLESS',
#  'PEERLESS': 'PRESLESS',
#  'PERRLESS': 'PRESLESS',
#  'PEERLESSAIN': 'PRESLESS',
#  'PEER;ESS': 'PRESLESS',
#  'PRESTIGE': 'PRESLESS',
#  'PEERLESS-SC': 'PRESLESS',
#  'PEERLES': 'PRESLESS',
#  'PRESTEGE': 'PRESLESS',
#  'PEERLESS GAS': 'PRESLESS',
#  'PREELESS': 'PRESLESS',
#  'CI PEERLESS': 'PRESLESS',
#  'PERLESS': 'PRESLESS',
#  'PEERELSS': 'PRESLESS',
#  'PEERELESS': 'PRESLESS',
#  'NEW PEERLESS': 'PRESLESS',
#  'PEERLESSS': 'PRESLESS',
#  'PEEERLESS': 'PRESLESS',
#  'PEERESSS': 'PRESLESS',
#  'PEERLESS NEW': 'PRESLESS',
#  'TRIANCO': 'TRIANCO',
#  'TEXACO': 'TRIANCO',
#  'TRIANGLE': 'TRIANCO',
#  'TRIAD PNCH 10': 'TRIANCO',
#  'TRIAD': 'TRIANCO',
#  'TRANE': 'TRIANCO',
#  'TRIANCO HTMAK': 'TRIANCO',
#  'TRIANCOHE': 'TRIANCO',
#  'TRIAD PNCH 15': 'TRIANCO',
#  'TRIANGLE ROAD': 'TRIANCO',
#  'TRI ANGLE': 'TRIANCO',
#  'SEARS': 'SEARS',
#  'STEAM': 'SEARS',
#  'SELLERS': 'SEARS',
#  'STEWART': 'SEARS',
#  'LARRS': 'SEARS',
#  'LLARS': 'SEARS',
#  'EDWARDS': 'SEARS',
#  'LARS': 'SEARS',
#  'LAARS': 'SEARS',
#  'EASCO': 'SEARS',
#  'RAYTHERM': 'RAYTHERM',
#  'HYFROTHERM': 'RAYTHERM',
#  'RAYTHERM H32100': 'RAYTHERM',
#  'CYCLOTHERM': 'RAYTHERM',
#  'HTDROTHERM': 'RAYTHERM',
#  'INFERNOTHERM': 'RAYTHERM',
#  'MIGHTY-THERM': 'RAYTHERM',
#  'HYRDOTHERM': 'RAYTHERM',
#  'HYDR0THERM': 'RAYTHERM',
#  'HYDRTHER': 'RAYTHERM',
#  'HYDROTHERIM': 'RAYTHERM',
#  'HYDRO THERM': 'RAYTHERM',
#  'HTHERM': 'RAYTHERM',
#  'HDROTHERM': 'RAYTHERM',
#  'HYROTHERM': 'RAYTHERM',
#  'CYCOTHERM': 'RAYTHERM',
#  'RAYTHERM EC106': 'RAYTHERM',
#  'HYDRTHERM': 'RAYTHERM',
#  'HYDROTHERM': 'RAYTHERM',
#  'RHEEM': 'RAYTHERM',
#  'HYDROTHERMN': 'RAYTHERM',
#  'NY THERMAL': 'RAYTHERM',
#  'RAYTHERM H3-': 'RAYTHERM',
#  'MIGHTY THERM': 'RAYTHERM',
#  'HYDOTHERM': 'RAYTHERM',
#  'THATCHER': 'RAYTHERM',
#  'HYDRTHRM': 'RAYTHERM',
#  'THERMFLO': 'RAYTHERM',
#  'WHIRLPOWER': 'WHIRLPOWER',
#  'WHIRL POOL': 'WHIRLPOWER',
#  'WORLD POWER': 'WHIRLPOWER',
#  'POWERS': 'WHIRLPOWER',
#  'RBI-DB-1500': 'RBI-DB-1500',
#  'RBI DB-1500': 'RBI-DB-1500',
#  'RBI-DB-1050': 'RBI-DB-1500',
#  'RBI-1500': 'RBI-DB-1500',
#  'RBI FW-1000': 'RBI-DB-1500',
#  'RBI-DB-1350': 'RBI-DB-1500',
#  'RBI/MB-2500': 'RBI-DB-1500',
#  'RBI FB-1500': 'RBI-DB-1500',
#  'RBI FB-1000': 'RBI-DB-1500',
#  'RBI DB 750': 'RBI-DB-1500',
#  'RBI MB-3000': 'RBI-DB-1500',
#  'RBI-MB-3000': 'RBI-DB-1500',
#  'RBI/MB2500': 'RBI-DB-1500',
#  'AMERICSTD': 'AMERICSTD',
#  'AMERIC STD': 'AMERICSTD',
#  'AM STD': 'AMERICSTD',
#  'AMERICAN STND': 'AMERICSTD',
#  'AMER  ST': 'AMERICSTD',
#  'AMER. STANDAR': 'AMERICSTD',
#  'AMERICAN S': 'AMERICSTD',
#  'AMSTD': 'AMERICSTD',
#  'AMERICAN-STAN': 'AMERICSTD',
#  'AMERICAN R': 'AMERICSTD',
#  'AMER-STANDARD': 'AMERICSTD',
#  'AMERICAM STANDARD': 'AMERICSTD',
#  'AMERICAN IDEA': 'AMERICSTD',
#  'AMER STND': 'AMERICSTD',
#  'AMERICAN STAND': 'AMERICSTD',
#  'AMERICAN STD.': 'AMERICSTD',
#  'AMERICAN STA': 'AMERICSTD',
#  'AMERICAN STAN': 'AMERICSTD',
#  'AMERICAN STANDARD': 'AMERICSTD',
#  'AMER STANDARD': 'AMERICSTD',
#  'AMER STAN': 'AMERICSTD',
#  'AM STND': 'AMERICSTD',
#  'AMERICANST': 'AMERICSTD',
#  'AMERICAN E': 'AMERICSTD',
#  'AMER  STD': 'AMERICSTD',
#  'AMERICAN STANDA': 'AMERICSTD',
#  'AMERICAN STAND.': 'AMERICSTD',
#  'AMERICAN  STD': 'AMERICSTD',
#  'AMERICAN STANDAR': 'AMERICSTD',
#  'AMERICANS': 'AMERICSTD',
#  'AMERICANSTANDARD': 'AMERICSTD',
#  'AMERICANSTAND': 'AMERICSTD',
#  'AME STD': 'AMERICSTD',
#  'AMERICAN IDEAL': 'AMERICSTD',
#  'W.MCLAIN': 'W.MCLAIN',
#  'WEIL MCLEAN': 'W.MCLAIN',
#  'WEIL.MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN B': 'W.MCLAIN',
#  'WAIL MCCLAIN': 'W.MCLAIN',
#  'WEIL MCCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 980': 'W.MCLAIN',
#  'WEIL MCLAIN L': 'W.MCLAIN',
#  'WEIL MCLAIN-CG6': 'W.MCLAIN',
#  'WEIL MLCAIN': 'W.MCLAIN',
#  'WEIL-MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAN': 'W.MCLAIN',
#  'WEIL MCLAINE': 'W.MCLAIN',
#  'WEIL MCLAI': 'W.MCLAIN',
#  'WEIL MCLAIN 888': 'W.MCLAIN',
#  'WEILMCLAI': 'W.MCLAIN',
#  'WEIL MCLAIN-5': 'W.MCLAIN',
#  'MCLAIN': 'W.MCLAIN',
#  'WEIL MCLIAN': 'W.MCLAIN',
#  'WEIL MCLAIN G': 'W.MCLAIN',
#  'WLMCLN': 'W.MCLAIN',
#  'WEIL MCLAIN-788': 'W.MCLAIN',
#  'WEILMC LAIN': 'W.MCLAIN',
#  'WEILMCLN': 'W.MCLAIN',
#  'W  MCLAN': 'W.MCLAIN',
#  'WIEL MCLAIN': 'W.MCLAIN',
#  'WEIL MCLIN': 'W.MCLAIN',
#  'WMCL': 'W.MCLAIN',
#  'WEILMCLIAN': 'W.MCLAIN',
#  'WEILCLAIN': 'W.MCLAIN',
#  'WEIL    MCLAIN': 'W.MCLAIN',
#  'WEIL MCAIN': 'W.MCLAIN',
#  'WEIL MCLAINEG': 'W.MCLAIN',
#  'WIL MCLAIN': 'W.MCLAIN',
#  'WLMCLAIN': 'W.MCLAIN',
#  'WEILMLCAIN': 'W.MCLAIN',
#  'WEIL-MCLAIN-E': 'W.MCLAIN',
#  'WEIL MCALIN': 'W.MCLAIN',
#  'WEIL MCLAIN EGH': 'W.MCLAIN',
#  'WELI MCLAI': 'W.MCLAIN',
#  'WEILOMCLAI': 'W.MCLAIN',
#  'WEIL MACLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 480': 'W.MCLAIN',
#  'WEILL MCLAIN': 'W.MCLAIN',
#  'WEI MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 680': 'W.MCLAIN',
#  'WEL MCLAIN': 'W.MCLAIN',
#  'WEIL-MCLAIN-P': 'W.MCLAIN',
#  'WEIL MCLAIN-E': 'W.MCLAIN',
#  'WEILMCLAINEG50': 'W.MCLAIN',
#  'WEILMCALIN': 'W.MCLAIN',
#  'WELIMCLAIN': 'W.MCLAIN',
#  'W MCLAIN': 'W.MCLAIN',
#  'WEILMCLAII': 'W.MCLAIN',
#  'WEIL MCLAIN D': 'W.MCLAIN',
#  'WEILMCLA': 'W.MCLAIN',
#  'W MICLAIN': 'W.MCLAIN',
#  'WEIL/MCLAIN': 'W.MCLAIN',
#  'CI WEIL MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN C': 'W.MCLAIN',
#  'WEIL MCLAIN.4': 'W.MCLAIN',
#  'WEILMLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN U': 'W.MCLAIN',
#  'WAIL MCLAI': 'W.MCLAIN',
#  'L MCLAIN': 'W.MCLAIN',
#  'WEILM CLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN LGB': 'W.MCLAIN',
#  'WMCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 5': 'W.MCLAIN',
#  'WEIL MCLLAIN': 'W.MCLAIN',
#  'WEIL MCLAIM': 'W.MCLAIN',
#  'WLMCN': 'W.MCLAIN',
#  'WL MCLAIN EGH': 'W.MCLAIN',
#  'WEIL MCLAIN F': 'W.MCLAIN',
#  'WEILMCLAIN1388': 'W.MCLAIN',
#  'WEIN MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN-488': 'W.MCLAIN',
#  'WEIL MCLAIN CGA': 'W.MCLAIN',
#  'WEILMCCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 66': 'W.MCLAIN',
#  'WEIL-MCLAIN 988': 'W.MCLAIN',
#  'WEILMKLAIN': 'W.MCLAIN',
#  'WEILMCAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 578': 'W.MCLAIN',
#  'WEIL MCLAIN 580': 'W.MCLAIN',
#  'WEILMCLAIN': 'W.MCLAIN',
#  'WEIL MCLAINEG40': 'W.MCLAIN',
#  'WEIL MALAIN': 'W.MCLAIN',
#  'WEILCMLAIN': 'W.MCLAIN',
#  'WEIL   MCLAIN': 'W.MCLAIN',
#  'WIEL MCLAIN 4': 'W.MCLAIN',
#  'WEIL  MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAINL': 'W.MCLAIN',
#  'WEIL MCLAIN#-': 'W.MCLAIN',
#  'WEIL MCLAIN-G': 'W.MCLAIN',
#  'WEIL MCLAIN E': 'W.MCLAIN',
#  'WEILMCLAINN': 'W.MCLAIN',
#  'WEIL MCLAIN S': 'W.MCLAIN',
#  'WEIIL MCLAIN': 'W.MCLAIN',
#  'WEIL- MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 1': 'W.MCLAIN',
#  'WEIL MCLAINCG': 'W.MCLAIN',
#  'WEIL MC LAIN': 'W.MCLAIN',
#  'WEILMCLAN': 'W.MCLAIN',
#  'WEIL MCLAIN 6': 'W.MCLAIN',
#  'WEILMACLIN': 'W.MCLAIN',
#  'WEIL MCLEIN': 'W.MCLAIN',
#  'WEIL MCLANN': 'W.MCLAIN',
#  'WEIL_MCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN 8': 'W.MCLAIN',
#  'WEIL CLAIN': 'W.MCLAIN',
#  'WEIL NCLAIN': 'W.MCLAIN',
#  'WIELMCLAIN': 'W.MCLAIN',
#  'MEILMCLAIN': 'W.MCLAIN',
#  'WEIL MCLAIN EG': 'W.MCLAIN',
#  'WEILMCL;AI': 'W.MCLAIN',
#  'WEIL MC LAINE': 'W.MCLAIN',
#  'WEIL MCLAIN EG-': 'W.MCLAIN',
#  'WEIL MCLAIN 7': 'W.MCLAIN',
#  'CROWN BOILER': 'CROWN BOILER',
#  'KEWANEE BOILER': 'CROWN BOILER',
#  'CROWN ARUB': 'CROWN BOILER',
#  'CROWN AL': 'CROWN BOILER',
#  'CROWN BS113': 'CROWN BOILER',
#  'US BOILER': 'CROWN BOILER',
#  'CROWN D': 'CROWN BOILER',
#  'NATCO BOIL': 'CROWN BOILER',
#  'KEWANEE BOILE': 'CROWN BOILER',
#  'TRIADBOILER': 'CROWN BOILER',
#  'AEO BOILER': 'CROWN BOILER',
#  'JOHNSON BOILER': 'CROWN BOILER',
#  'BURNHAM BOILE': 'CROWN BOILER',
#  'TRIAD BOILER': 'CROWN BOILER',
#  'EASCO BOILER CORP.': 'CROWN BOILER',
#  'CROWN BOILA': 'CROWN BOILER',
#  'COLUMBIA BOILER CO': 'CROWN BOILER',
#  'CROWM BLRS': 'CROWN BOILER',
#  'CE BOILER': 'CROWN BOILER',
#  'CROWN ABF': 'CROWN BOILER',
#  'MOBIL BOILER': 'CROWN BOILER',
#  'OSB BOILER': 'CROWN BOILER',
#  'NYBOILER': 'CROWN BOILER',
#  'PENN BOILER': 'CROWN BOILER',
#  'EASCO BOILER': 'CROWN BOILER',
#  'CROWN AW': 'CROWN BOILER',
#  'JOHNSTON BOILER': 'CROWN BOILER',
#  'BURNHAM BOILERS': 'CROWN BOILER',
#  'CROWN ARUBA': 'CROWN BOILER',
#  'AMERICAN BOILER': 'CROWN BOILER',
#  'SERS BOILER': 'CROWN BOILER',
#  'USBOILER': 'CROWN BOILER',
#  'KWANNE BOILER': 'CROWN BOILER',
#  'NATIONAL BOILER': 'CROWN BOILER',
#  'BEST BOILER': 'CROWN BOILER',
#  'BURNHAM BOILER': 'CROWN BOILER',
#  'PENNBOILER': 'CROWN BOILER',
#  'BURNHAM 1N-4': 'BURNHAM 1N-4',
#  'BURNHAM 204 N': 'BURNHAM 1N-4',
#  'BURNHAM IN 6': 'BURNHAM 1N-4',
#  'BURNHAM *': 'BURNHAM 1N-4',
#  'BURHAN': 'BURNHAM 1N-4',
#  'BURHNAM': 'BURNHAM 1N-4',
#  'BURNAM': 'BURNHAM 1N-4',
#  'BURHAM': 'BURNHAM 1N-4',
#  'BURNHAM': 'BURNHAM 1N-4',
#  'BURNHAM IN-9': 'BURNHAM 1N-4',
#  'BURNHAM 206NCL-TEI2': 'BURNHAM 1N-4',
#  'BURNHAM-KIN-6': 'BURNHAM 1N-4',
#  'BURNHAM SER2T': 'BURNHAM 1N-4',
#  'BURNHAM V911A': 'BURNHAM 1N-4',
#  'BURFNAHM': 'BURNHAM 1N-4',
#  'BURNHAM V-904': 'BURNHAM 1N-4',
#  'BURNHAM EG-65': 'BURNHAM 1N-4',
#  'BURNAHAM': 'BURNHAM 1N-4',
#  'BURNHAM SIN6': 'BURNHAM 1N-4',
#  'BURNHAM KIN': 'BURNHAM 1N-4',
#  'BURNHAM IN 7': 'BURNHAM 1N-4',
#  'BURNHAM 206PV': 'BURNHAM 1N-4',
#  'BURNHAM IN-6': 'BURNHAM 1N-4',
#  'BURNHAM V907': 'BURNHAM 1N-4',
#  'BURNHAM IN-5': 'BURNHAM 1N-4',
#  'BURNHAM P-208A': 'BURNHAM 1N-4',
#  'BURNHAM MPC-6': 'BURNHAM 1N-4',
#  'BURNHAMS': 'BURNHAM 1N-4',
#  'BURNHAM KING': 'BURNHAM 1N-4',
#  'BURNHAM  IN-9': 'BURNHAM 1N-4',
#  'BURNHAM-SIN-5': 'BURNHAM 1N-4',
#  'BURNHAM MPC10': 'BURNHAM 1N-4',
#  'BURNHAM ANZ21': 'BURNHAM 1N-4',
#  'BURNHAM IN8': 'BURNHAM 1N-4',
#  'BURNHAM MPC 11': 'BURNHAM 1N-4',
#  'BURNHAM K5010': 'BURNHAM 1N-4',
#  'BURNHAM V90': 'BURNHAM 1N-4',
#  'BURNHAM KIN6': 'BURNHAM 1N-4',
#  'BURNHAM SIN7LNC-LE2': 'BURNHAM 1N-4',
#  'BURNHAM KV91': 'BURNHAM 1N-4',
#  'BURNHAM -SPENCER': 'BURNHAM 1N-4',
#  'BURNHAM HOLID': 'BURNHAM 1N-4',
#  'BURMHAM': 'BURNHAM 1N-4',
#  'M* BURNHAM': 'BURNHAM 1N-4',
#  'BURNHAM HYDRO': 'BURNHAM 1N-4',
#  'BURNHAM IN6': 'BURNHAM 1N-4',
#  'BURNHAM 210NCL': 'BURNHAM 1N-4',
#  'BURNHAM KIN-0': 'BURNHAM 1N-4',
#  'BURNHAMLAIN': 'BURNHAM 1N-4',
#  'BURNHAMN': 'BURNHAM 1N-4',
#  'BURNHAM-AMER': 'BURNHAM 1N-4',
#  'BURNHAM  IN': 'BURNHAM 1N-4',
#  'BURNHAM 206-N': 'BURNHAM 1N-4',
#  'BURNAHM': 'BURNHAM 1N-4',
#  'BURNHAMH': 'BURNHAM 1N-4',
#  'BURNHAM IN7': 'BURNHAM 1N-4',
#  'BURNHAM KIN-9': 'BURNHAM 1N-4',
#  'BURNHAM 3W-150-50': 'BURNHAM 1N-4',
#  'BURNHAM MPC4': 'BURNHAM 1N-4',
#  'BURNHAM P810HNEI-L2': 'BURNHAM 1N-4',
#  'BURNHAM  STD': 'BURNHAM 1N-4',
#  'BURNHAM MP': 'BURNHAM 1N-4',
#  'BURNHAM IN-4': 'BURNHAM 1N-4',
#  'NEW BURNHAM': 'BURNHAM 1N-4',
#  'BURNHAM V905': 'BURNHAM 1N-4',
#  'BURNHAM P810HNE1-L2': 'BURNHAM 1N-4',
#  'BURNHAM 205': 'BURNHAM 1N-4',
#  'BURNHAM-206 NCL': 'BURNHAM 1N-4',
#  'BUNHAM': 'BURNHAM 1N-4',
#  'BURNHAM V-905': 'BURNHAM 1N-4',
#  'BURNHARM': 'BURNHAM 1N-4',
#  'BURNHAM IN-11': 'BURNHAM 1N-4',
#  'BURNHAM K5000': 'BURNHAM 1N-4',
#  'BURNHAM AMER': 'BURNHAM 1N-4',
#  'BURNHAM P 207': 'BURNHAM 1N-4',
#  'BURNHAM-MST51': 'BURNHAM 1N-4',
#  'BURNHAM V-906': 'BURNHAM 1N-4',
#  'BURNHAM  IN-6': 'BURNHAM 1N-4',
#  'BURNHAN': 'BURNHAM 1N-4',
#  'BUNRHAM': 'BURNHAM 1N-4',
#  'BRUNHAM': 'BURNHAM 1N-4',
#  'BURNHAM AMC': 'BURNHAM 1N-4',
#  'BURNHAM V911 A': 'BURNHAM 1N-4',
#  'BURNHAM IN-10': 'BURNHAM 1N-4',
#  'BURNHAM     4': 'BURNHAM 1N-4',
#  'BURNHAM KIN-1': 'BURNHAM 1N-4',
#  'BURNHAM IN12N': 'BURNHAM 1N-4',
#  'BURNHAM 202': 'BURNHAM 1N-4',
#  'BURN HAM': 'BURNHAM 1N-4',
#  'BURNHAM K500-8B': 'BURNHAM 1N-4',
#  'BURNHAM V912': 'BURNHAM 1N-4',
#  'BURNHAM V904': 'BURNHAM 1N-4',
#  'BURNHAM IN-7': 'BURNHAM 1N-4',
#  'BURNHAM - P209': 'BURNHAM 1N-4',
#  'BURNHAM&QSIN': 'BURNHAM 1N-4',
#  'BURNHAM 404B': 'BURNHAM 1N-4',
#  'CI BURNHAM': 'BURNHAM 1N-4',
#  'BURNHAM.405-B': 'BURNHAM 1N-4',
#  'BURNHAM (STEA': 'BURNHAM 1N-4',
#  'BURNHAM P206-W': 'BURNHAM 1N-4',
#  'BURNHMA': 'BURNHAM 1N-4',
#  'BURNHAM V85S': 'BURNHAM 1N-4',
#  'BURNHA': 'BURNHAM 1N-4',
#  'BURNHAM AMERI': 'BURNHAM 1N-4',
#  'PRESTIGE SOLO': 'PRESTIGE SOLO',
#  'TRI TUBE SOLO': 'PRESTIGE SOLO',
#  'TRIANGLE PRESTIGE': 'TRIANGLE PRESTIGE',
#  'TRIANGLE TUB': 'TRIANGLE PRESTIGE',
#  'TRIANGULAR TU': 'TRIANGLE PRESTIGE',
#  'TRAINGLE TUBE': 'TRIANGLE PRESTIGE',
#  'TRIANGLE  TUB': 'TRIANGLE PRESTIGE',
#  'TRIANGLETUBE': 'TRIANGLE PRESTIGE',
#  'TRIANGLE TU': 'TRIANGLE PRESTIGE',
#  'TRIANGLE.TUBE': 'TRIANGLE PRESTIGE',
#  'TRIANGLE TUBE': 'TRIANGLE PRESTIGE',
#  'CROWN JAMAICA': 'CROWN JAMAICA',
#  'CROWN / ARUBA': 'CROWN JAMAICA',
#  'GREEN MNTN': 'GREEN MNTN',
#  'GREENMOUNT': 'GREEN MNTN',
#  'GREENMOUTAIN': 'GREEN MNTN',
#  'GREENMOUNTAIN': 'GREEN MNTN',
#  'GREEN MTN': 'GREEN MNTN',
#  'GRN MOUNT': 'GREEN MNTN',
#  'GREEN MOUNTAIN': 'GREEN MNTN',
#  'GREENMTN': 'GREEN MNTN',
#  'GREEN MOUN': 'GREEN MNTN',
#  'GREENMNTN': 'GREEN MNTN',
#  'GREEEN  MOUNT': 'GREEN MNTN',
#  'GREEN MOUNTAI': 'GREEN MNTN',
#  'GREEN MOUNT': 'GREEN MNTN',
#  'BECKETT': 'BECKETT',
#  'EASCO FPS-500': 'EASCO FPS-500',
#  'FEDERAL FST-500': 'EASCO FPS-500',
#  'EASCO ESP-125': 'EASCO FPS-500',
#  'NATCO F85-030': 'EASCO FPS-500',
#  'NATCO PW-400': 'EASCO FPS-500',
#  'EASCO   FTSM': 'EASCO FPS-500',
#  'EASCO/FTSM': 'EASCO FPS-500',
#  'AERCI': 'AERCI',
#  'AERO': 'AERCI',
#  'AERCO`': 'AERCI',
#  'AERCOFIN': 'AERCI',
#  'NARCO': 'AERCI',
#  'AEWRCO': 'AERCI',
#  'ERIE': 'AERCI',
#  'AERCO KC': 'AERCI',
#  'ARCO': 'AERCI',
#  'AERCO': 'AERCI',
#  'CLEAVER BROOKS M143-': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOK': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER BRROKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKS D-34-': 'CLEAVER BROOKS M143-',
#  'CLEAVERBROOKS C': 'CLEAVER BROOKS M143-',
#  'CLEAVER BR': 'CLEAVER BROOKS M143-',
#  'CLEAVER.BROOK': 'CLEAVER BROOKS M143-',
#  'M* CLEAVERBRO': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKKS': 'CLEAVER BROOKS M143-',
#  'CLEVER BROOKS': 'CLEAVER BROOKS M143-',
#  'CLEVER BR': 'CLEAVER BROOKS M143-',
#  'CLEVERBROOK C': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKS CB 20': 'CLEAVER BROOKS M143-',
#  'CLEVER BRO': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKER': 'CLEAVER BROOKS M143-',
#  'CLEAVERBK': 'CLEAVER BROOKS M143-',
#  'CLEVERBROOK': 'CLEAVER BROOKS M143-',
#  'CLEABER BROOK': 'CLEAVER BROOKS M143-',
#  'CLEVEBROOK': 'CLEAVER BROOKS M143-',
#  'CLEAVERBR': 'CLEAVER BROOKS M143-',
#  'CLEV BROOK': 'CLEAVER BROOKS M143-',
#  'CLEAVEER BROOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVERBRO': 'CLEAVER BROOKS M143-',
#  'CLEAVER-BROOK': 'CLEAVER BROOKS M143-',
#  'CLEAVEBROO': 'CLEAVER BROOKS M143-',
#  'CLEAVERBROOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER BK': 'CLEAVER BROOKS M143-',
#  'CLEAVERBROOK': 'CLEAVER BROOKS M143-',
#  'M* CLEAVERBROOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER -BROOKS': 'CLEAVER BROOKS M143-',
#  'CLEVERBROOKS': 'CLEAVER BROOKS M143-',
#  'CLEAVER BROOKE': 'CLEAVER BROOKS M143-',
#  'CLEVER-BROOKS': 'CLEAVER BROOKS M143-',
#  'CLAVER BROOKS': 'CLEAVER BROOKS M143-',
#  'TELEDYNE LARR': 'TELEDYNE LARR',
#  'TELEDYNE/L': 'TELEDYNE LARR',
#  'TELEDYNE LEARS': 'TELEDYNE LARR',
#  'TELEDYNE LAARS  PH-0': 'TELEDYNE LARR',
#  'TELEDYNE LAARS PW060': 'TELEDYNE LARR',
#  'TELEDYNELARRS': 'TELEDYNE LARR',
#  'TRELEDYNE LAA': 'TELEDYNE LARR',
#  'TELEDYNE LAAR': 'TELEDYNE LARR',
#  'TELDYNE LAARS': 'TELEDYNE LARR',
#  'TYLEDYNE LARS': 'TELEDYNE LARR',
#  'TELEDYNE LARRS': 'TELEDYNE LARR',
#  'TELEDYNE-LAAR': 'TELEDYNE LARR',
#  'TELEDYNELAARS': 'TELEDYNE LARR',
#  'TELEDYNEL': 'TELEDYNE LARR',
#  'TELEDYNELA': 'TELEDYNE LARR',
#  'TELEYNE LAARS': 'TELEDYNE LARR',
#  'TELEDYNE THAR': 'TELEDYNE LARR',
#  'TELDYNE': 'TELEDYNE LARR',
#  'TYLEDYNE LAARS': 'TELEDYNE LARR',
#  'TELEDYNE LAARS PH-04': 'TELEDYNE LARR',
#  'TELEDYNE LAYS': 'TELEDYNE LARR',
#  'TLDYNDAARS': 'TELEDYNE LARR',
#  'TELEDYNE LAAR-PW0999': 'TELEDYNE LARR',
#  'TELEDYNE LAARS PH-03': 'TELEDYNE LARR',
#  'TELEDYNE LAA': 'TELEDYNE LARR',
#  'TELEDYNE': 'TELEDYNE LARR',
#  'TELEDYNE LEAR': 'TELEDYNE LARR',
#  'TELDYNE LARRS': 'TELEDYNE LARR',
#  'TELEDYDE L': 'TELEDYNE LARR',
#  'TELEDYNELARS': 'TELEDYNE LARR',
#  'TELEDYNE L': 'TELEDYNE LARR',
#  'TELEDYNE LAARS': 'TELEDYNE LARR',
#  'TELEDYNE/LAAR': 'TELEDYNE LARR',
#  'TELEDYNE-LAARS': 'TELEDYNE LARR',
#  'TELEDYS LAARS': 'TELEDYNE LARR',
#  'TLDYNLAARS': 'TELEDYNE LARR',
#  'TELEDYNE LARS': 'TELEDYNE LARR',
#  'TELE LAARS': 'TELEDYNE LARR',
#  'TELEDYME LAARS': 'TELEDYNE LARR',
#  'TELEDYNE  LAR': 'TELEDYNE LARR',
#  'MURRAY': 'MURRAY',
#  'TRANE MURRAY': 'MURRAY',
#  'RAY': 'MURRAY',
#  'BURKAY': 'MURRAY',
#  'FULTON105382': 'FULTON105382',
#  'FULTON 112478': 'FULTON105382',
#  'FULTON 89853': 'FULTON105382',
#  'FULTON 41423': 'FULTON105382',
#  'FULTON 53711': 'FULTON105382',
#  'FULTON 117322': 'FULTON105382',
#  'FULTON FB-015': 'FULTON105382',
#  'FULTON 102510': 'FULTON105382',
#  'FULTON 103055': 'FULTON105382',
#  'FULTON105370': 'FULTON105382',
#  'FULTON 109680': 'FULTON105382',
#  'FULTON 109779': 'FULTON105382',
#  'FULTON 103068': 'FULTON105382',
#  'FULTON 015NB 12': 'FULTON105382',
#  'FULTON80334': 'FULTON105382',
#  'FULTON 104693': 'FULTON105382',
#  'FULTON 103061': 'FULTON105382',
#  'FULTON 41820': 'FULTON105382',
#  'FULTON-94085-': 'FULTON105382',
#  'FULTON 110146': 'FULTON105382',
#  'FULTON 101718': 'FULTON105382',
#  'FULTON 112482': 'FULTON105382',
#  'FULTON80339': 'FULTON105382',
#  'FULTON 66535': 'FULTON105382',
#  'FULTON 010': 'FULTON105382',
#  'FULTON 40003': 'FULTON105382',
#  'FULTON-15 HP': 'FULTON105382',
#  'FULTON FB-020': 'FULTON105382',
#  'FULTON FB010-A': 'FULTON105382',
#  'FULTON 66518': 'FULTON105382',
#  'FULTON 49078': 'FULTON105382',
#  'FULTON83732': 'FULTON105382',
#  'FULTON': 'FULTON105382',
#  'FULTON 93132': 'FULTON105382',
#  'FULTON 91872': 'FULTON105382',
#  'FULTON 38480': 'FULTON105382',
#  'FULTON 110142': 'FULTON105382',
#  'FULTON 117327': 'FULTON105382',
#  'FULTON 10HP': 'FULTON105382',
#  'FULTON 109682': 'FULTON105382',
#  'FULTON 78252': 'FULTON105382',
#  'FULTON NB 12092': 'FULTON105382',
#  'FULTON 101574': 'FULTON105382',
#  'FULTON 43428': 'FULTON105382',
#  'FULTON 116002': 'FULTON105382',
#  'FULTON 105489': 'FULTON105382',
#  'FULTON115110': 'FULTON105382',
#  'FULTON 81061': 'FULTON105382',
#  'FULTON 111218': 'FULTON105382',
#  'FULTON/FB-015': 'FULTON105382',
#  'FULTON 1CX20': 'FULTON105382',
#  'FULTON F-10': 'FULTON105382',
#  'FULTON 108370': 'FULTON105382',
#  'FEDERAL PLW 53HW': 'FEDERAL PLW 53HW',
#  'FEDERAL ESP-8': 'FEDERAL PLW 53HW',
#  'FEDERAL FST-5': 'FEDERAL PLW 53HW',
#  'FEDERAL FST 350 HW': 'FEDERAL PLW 53HW',
#  'FEDERAL BOILE': 'FEDERAL PLW 53HW',
#  'FEDERAL FST/3': 'FEDERAL PLW 53HW',
#  'FEDERAL FST-3': 'FEDERAL PLW 53HW',
#  'FEDERAL FST-50': 'FEDERAL PLW 53HW',
#  'FEDERAL FLR36': 'FEDERAL PLW 53HW',
#  'FEDERAL FLW 6071': 'FEDERAL PLW 53HW',
#  'FEDERAL FST 2': 'FEDERAL PLW 53HW',
#  'FEDERAL FST-150 HW': 'FEDERAL PLW 53HW',
#  'FEDERAL FST-32': 'FEDERAL PLW 53HW',
#  'FEDERAL FST 7': 'FEDERAL PLW 53HW',
#  'FEDERAL FST 125': 'FEDERAL PLW 53HW',
#  'FEDERAL FST 1': 'FEDERAL PLW 53HW',
#  'FEDERAL BO': 'FEDERAL PLW 53HW',
#  'FEDERAL': 'FEDERAL PLW 53HW',
#  'FEDERAL FLW-1215': 'FEDERAL PLW 53HW',
#  'BEST 5D-450': 'BEST 5D-450',
#  'BEST 5D-300': 'BEST 5D-450',
#  'BEST 5C175': 'BEST 5D-450',
#  'BEST 5B-60': 'BEST 5D-450',
#  'BEST 5C-150': 'BEST 5D-450',
#  'BEST-5D-450': 'BEST 5D-450',
#  'BEST BOILER 5B-50': 'BEST 5D-450',
#  'BEST-5C-90': 'BEST 5D-450',
#  'BEST 5B-80': 'BEST 5D-450',
#  'BEST-4A-55': 'BEST 5D-450',
#  'BEST 5D-350': 'BEST 5D-450',
#  'M*BEST 5C-300': 'BEST 5D-450',
#  'BEST 5A50': 'BEST 5D-450',
#  'BEST 5C-100': 'BEST 5D-450',
#  'BEST 4B-70': 'BEST 5D-450',
#  'NATIONAL.U.S': 'NATIONAL.U.S',
#  'US NATIONAL N': 'NATIONAL.U.S',
#  'NATION': 'NATIONAL.U.S',
#  'U.S.NATIONAL': 'NATIONAL.U.S',
#  'NATIONAL 6-16': 'NATIONAL.U.S',
#  'NATIONAL U.S.': 'NATIONAL.U.S',
#  'U SNATIONAL': 'NATIONAL.U.S',
#  'NATIONAL U.S': 'NATIONAL.U.S',
#  'NATIONAL RADI': 'NATIONAL.U.S',
#  'H.W.NATIONAL': 'NATIONAL.U.S',
#  'US NATIONA': 'NATIONAL.U.S',
#  'NATIONAL R': 'NATIONAL.U.S',
#  'NATIONAL US': 'NATIONAL.U.S',
#  'U.S. NATIONAL': 'NATIONAL.U.S',
#  'NATIONAL  RAD': 'NATIONAL.U.S',
#  'NATION RAD': 'NATIONAL.U.S',
#  'US NATIONAL 6': 'NATIONAL.U.S',
#  'NATIONAL RAD': 'NATIONAL.U.S',
#  'NATIONAL 8-16': 'NATIONAL.U.S',
#  'NATIONALUS': 'NATIONAL.U.S',
#  'U.S NATIONAL': 'NATIONAL.U.S',
#  'US NATIONAL': 'NATIONAL.U.S',
#  'USNATIONAL': 'NATIONAL.U.S',
#  'NATIONAL U': 'NATIONAL.U.S',
#  'NATIONAL BOIL': 'NATIONAL.U.S',
#  'U S NATIONAL': 'NATIONAL.U.S',
#  'NATIONAL 6C': 'NATIONAL.U.S',
#  'NATIONAL': 'NATIONAL.U.S',
#  'NATIONALU': 'NATIONAL.U.S',
#  'NATIONAL US R': 'NATIONAL.U.S',
#  'USNATIONA': 'NATIONAL.U.S',
#  'NATIONAL 5-16': 'NATIONAL.U.S',
#  'NATIONAL HEAT': 'NATIONAL.U.S',
#  'NATIONAL SERI': 'NATIONAL.U.S',
#  'INTERNATIONAL': 'NATIONAL.U.S',
#  'US. NATIONAL': 'NATIONAL.U.S',
#  'NR C': 'NR C',
#  'US NRC': 'NR C',
#  'NRC-US': 'NR C',
#  'N R C': 'NR C',
#  'NRC US': 'NR C',
#  'N.R.C': 'NR C',
#  'NRC': 'NR C',
#  'IBW CO': 'IBW CO',
#  'ABCO': 'IBW CO',
#  'EXBROOKE': 'EXBROOKE',
#  'AMER EXTBROOK': 'EXBROOKE',
#  'AMER EXBROOK': 'EXBROOKE',
#  'EXBROOK': 'EXBROOKE',
#  'AM.EXBROOK 20': 'EXBROOKE',
#  'KOEHLER': 'KOEHLER',
#  'KEELER': 'KOEHLER',
#  'KOHLER': 'KOEHLER',
#  'KOLHER': 'KOEHLER',
#  'NRC / US': 'NRC / US',
#  'N.R.C. U.S': 'NRC / US',
#  'MAGIC SERVENT': 'MAGIC SERVENT',
#  'PENNCO #1506': 'PENNCO #1506',
#  'PENCO 15B-245': 'PENNCO #1506',
#  'PENNCO4KS150': 'PENNCO #1506',
#  'PENNCO IND': 'PENNCO #1506',
#  'PENCO10/31': 'PENNCO #1506',
#  'PENNCO': 'PENNCO #1506',
#  'PENCO 1605-HS': 'PENNCO #1506',
#  'HYDRO': 'HYDRO',
#  'HYDROTHRM': 'HYDRO',
#  'HYDROTH': 'HYDRO',
#  'HYDRO THRM': 'HYDRO',
#  'HYDROTHR': 'HYDRO',
#  'HYDROTERM': 'HYDRO',
#  'HYDROTHREM': 'HYDRO',
#  'HYDROHERM': 'HYDRO',
#  'HYDROTHE': 'HYDRO',
#  'HYDROTHERN': 'HYDRO',
#  'HYDRO/PULSE': 'HYDRO',
#  'HYDROTHEM': 'HYDRO',
#  'HYDROPHINE': 'HYDRO',
#  'HYDRONICS': 'HYDRO',
#  'HYDROTHER': 'HYDRO',
#  'SUPERIOR': 'SUPERIOR',
#  'SUPERIOR BOIL': 'SUPERIOR',
#  'SUPERIOR 350': 'SUPERIOR',
#  'PETRO': 'SUPERIOR',
#  'SUPERSTAR': 'SUPERIOR',
#  'SUPEREME': 'SUPERIOR',
#  'SUPERME': 'SUPERIOR',
#  'PEBCO S 04': 'PEBCO S 04',
#  'PEBCO': 'PEBCO S 04',
#  'BUDERUS G-45234 X': 'BUDERUS G-45234 X',
#  'BUDERUS GB162-8': 'BUDERUS G-45234 X',
#  'BUDERUS GB162-80': 'BUDERUS G-45234 X',
#  'BUDERUS LOGAN': 'BUDERUS G-45234 X',
#  'BUDERUS GA-24': 'BUDERUS G-45234 X',
#  'RHEEM-RUUD': 'RHEEM-RUUD',
#  'RHEEM RUUD': 'RHEEM-RUUD',
#  'RHEEM/RUUD': 'RHEEM-RUUD',
#  'HB SMITH 28A7': 'HB SMITH 28A7',
#  'H. B.SMITH': 'HB SMITH 28A7',
#  'HB SMITH 28-11': 'HB SMITH 28A7',
#  'H B SMIT': 'HB SMITH 28A7',
#  'HBSMTIH': 'HB SMITH 28A7',
#  'H.B.SMITH 28': 'HB SMITH 28A7',
#  'H.B SMTIH': 'HB SMITH 28A7',
#  'HB SMITH 19A-11': 'HB SMITH 28A7',
#  'H BSMIT': 'HB SMITH 28A7',
#  'HB SMITH 28': 'HB SMITH 28A7',
#  'H.B. SMITH 19': 'HB SMITH 28A7',
#  'HB SMITH 28-10': 'HB SMITH 28A7',
#  'H B  SMITH': 'HB SMITH 28A7',
#  'H.B.SMITH_G28': 'HB SMITH 28A7',
#  'H.BSMITH': 'HB SMITH 28A7',
#  'H B SMITH 28-9': 'HB SMITH 28A7',
#  'H B SMITH': 'HB SMITH 28A7',
#  'HB SMITH 28-8': 'HB SMITH 28A7',
#  'H.B SMITH': 'HB SMITH 28A7',
#  'HB SMITH 19-7': 'HB SMITH 28A7',
#  'HB SMITH': 'HB SMITH 28A7',
#  'H. B.. SMITH': 'HB SMITH 28A7',
#  'H B SMITH G 28 G': 'HB SMITH 28A7',
#  'HB SMITH 28-9': 'HB SMITH 28A7',
#  'H BSMITH': 'HB SMITH 28A7',
#  'HB SMITH 19A-S/W-05': 'HB SMITH 28A7',
#  'HBSMITH 28-9': 'HB SMITH 28A7',
#  'HBSHMITH': 'HB SMITH 28A7',
#  'HB SMITH 19-8': 'HB SMITH 28A7',
#  'HB SMIITH': 'HB SMITH 28A7',
#  'B-1 SMITH': 'HB SMITH 28A7',
#  'H.B SMI TH': 'HB SMITH 28A7',
#  'HBSMITH28-8': 'HB SMITH 28A7',
#  'SMITH.28-A-8': 'HB SMITH 28A7',
#  'H.B.SMITH H': 'HB SMITH 28A7',
#  'HB.SMITH': 'HB SMITH 28A7',
#  'NEW HB SMITH': 'HB SMITH 28A7',
#  'HBSMITH 28-8': 'HB SMITH 28A7',
#  'HB SMITH 20': 'HB SMITH 28A7',
#  'H.B.SMITH-G28': 'HB SMITH 28A7',
#  'HB SMITH 28S': 'HB SMITH 28A7',
#  'HB SMITH 28A-9': 'HB SMITH 28A7',
#  'HB SMITH-G028': 'HB SMITH 28A7',
#  'H.B.SMITH': 'HB SMITH 28A7',
#  'HB SMITH 28A8': 'HB SMITH 28A7',
#  'HB SMITH-2500': 'HB SMITH 28A7',
#  'H.B.SMITHH': 'HB SMITH 28A7',
#  'C1 HB SMITH': 'HB SMITH 28A7',
#  'H.B. SMITH': 'HB SMITH 28A7',
#  'HB. SMITH': 'HB SMITH 28A7',
#  'H.B.SMITH 28HE-': 'HB SMITH 28A7',
#  'H B SMITH 19-': 'HB SMITH 28A7',
#  'HBSMITH': 'HB SMITH 28A7',
#  'SMITHAO': 'HB SMITH 28A7',
#  'HBSMITH 28A-8': 'HB SMITH 28A7',
#  'H B SMITH (NEW)': 'HB SMITH 28A7',
#  'HB SMITH 28A-8': 'HB SMITH 28A7',
#  'HBSMITH 28A-9': 'HB SMITH 28A7',
#  'B SMITH': 'HB SMITH 28A7',
#  'H B SMI': 'HB SMITH 28A7',
#  'H. B. SMITH': 'HB SMITH 28A7',
#  'H.B .SMITH': 'HB SMITH 28A7',
#  'H.B.SMITH 621': 'HB SMITH 28A7',
#  'HB SMITH 19-1': 'HB SMITH 28A7',
#  'B. SMITH': 'HB SMITH 28A7',
#  'HBH SMITH': 'HB SMITH 28A7',
#  'H..B.SMITH': 'HB SMITH 28A7',
#  'HB SMITH 28A-': 'HB SMITH 28A7',
#  'HBSMITH 3500A-6': 'HB SMITH 28A7',
#  'HB SMITH 19-6': 'HB SMITH 28A7',
#  'H.B. SMITH28A-7': 'HB SMITH 28A7',
#  'HB SMITH MILL': 'HB SMITH 28A7',
#  'HBSMITH 28-10': 'HB SMITH 28A7',
#  'H. B. SMITH 250': 'HB SMITH 28A7',
#  'HB SNITH': 'HB SMITH 28A7',
#  'H.S. SMITH': 'HB SMITH 28A7',
#  'HB  SMITH': 'HB SMITH 28A7',
#  'SMITH AO': 'HB SMITH 28A7',
#  'HB SMITH 19-5': 'HB SMITH 28A7',
#  'HB-SMITH': 'HB SMITH 28A7',
#  'H/B SMITH': 'HB SMITH 28A7',
#  'HB SMTIH': 'HB SMITH 28A7',
#  'HB SMIT': 'HB SMITH 28A7',
#  'H.B.SMITH G28': 'HB SMITH 28A7',
#  'HB SMITH 19A-SW7': 'HB SMITH 28A7',
#  'AERCO BMK-30': 'AERCO BMK-30',
#  'AERCO BMK-1.5': 'AERCO BMK-30',
#  'AERCO/BMK200': 'AERCO BMK-30',
#  'AERCO KC-1000': 'AERCO BMK-30',
#  'AERCO BMK-3000': 'AERCO BMK-30',
#  'AERCO BMK 3.0': 'AERCO BMK-30',
#  'AERCO BMK-2': 'AERCO BMK-30',
#  'AERCO BMK-2000': 'AERCO BMK-30',
#  'AERO BMK  2.0LN': 'AERCO BMK-30',
#  'AERCO BENCHMA': 'AERCO BMK-30',
#  'AERCO KC 1000': 'AERCO BMK-30',
#  'AERCO BMK-20L': 'AERCO BMK-30',
#  'AERCO BENCHMARK 3.0': 'AERCO BMK-30',
#  'AERCO BMK-600': 'AERCO BMK-30',
#  'AERCO BMK2': 'AERCO BMK-30',
#  'AERCO BMK-2.0': 'AERCO BMK-30',
#  'AERCO BENCHMARK': 'AERCO BMK-30',
#  'AERCO BMK 200': 'AERCO BMK-30',
#  'AERCO BMK-6.0': 'AERCO BMK-30',
#  'AERCO BMK': 'AERCO BMK-30',
#  'AERCI BMK-3.0': 'AERCO BMK-30',
#  'AERCO BMK-3-OCN': 'AERCO BMK-30',
#  'AERCO BMK-3.0': 'AERCO BMK-30',
#  'INDECK LAMONT': 'INDECK LAMONT',
#  'INT. LAMONT': 'INDECK LAMONT',
#  'INDECK': 'INDECK LAMONT',
#  'HB SMITH GB100-W-5CO': 'HB SMITH GB100-W-5CO',
#  'FUTERA 11 FB': 'FUTERA 11 FB',
#  'FUTURA RB': 'FUTERA 11 FB',
#  'FUTERA II': 'FUTERA 11 FB',
#  'RBI FUTERA 11': 'FUTERA 11 FB',
#  'FUTERA FUSION': 'FUTERA 11 FB',
#  'FUTERA RBI': 'FUTERA 11 FB',
#  'FUTERA': 'FUTERA 11 FB',
#  'FUTERA II RBI': 'FUTERA 11 FB',
#  'RB1 FUTERA 11': 'FUTERA 11 FB',
#  'ROCKMILLS MP100': 'ROCKMILLS MP100',
#  'ROCKMILLS STEEL': 'ROCKMILLS MP100',
#  ...}

# %%
# complete the mapping
boiler_inspections['Boiler Make'] = boiler_inspections['Boiler Make'].map(inverted_makes)

# %% [markdown]
# ### Question: What are the most popular boilers?

# %%
top_makes = boiler_inspections.groupby('Boiler Make').count().sort_values(by='Bin Number', ascending=False)['Tracking Number'].head()
top_makes
# Out:
# Boiler Make
# W.MCLAIN            32713
# FEDERAL PLW 53HW    17583
# BURNHAM 1N-4        14385
# HB SMITH 28A7       12159
# ROCKMILLS MP100     11021
# Name: Tracking Number, dtype: int64

# %% [markdown]
# ### Question: Which boiler makes have the highest rate of defects?

# %%
boiler_make_numerator = boiler_inspections.groupby('Boiler Make').sum()['Defects Exist']

boiler_make_denominator = boiler_inspections.groupby('Boiler Make').count()['Boiler ID']

defect_make_ratio = boiler_make_numerator / boiler_make_denominator

# %%
# of the top 5 boilers, which are the most defective?
for make in top_makes.index:
    print("Make: {} ---- defect ratio: {}".format(make, defect_make_ratio[make]))
    print()
# Out:
# Make: W.MCLAIN ---- defect ratio: 0.0755357197444441
#
# Make: FEDERAL PLW 53HW ---- defect ratio: 0.09964169936870841
#
# Make: BURNHAM 1N-4 ---- defect ratio: 0.06506777893639208
#
# Make: HB SMITH 28A7 ---- defect ratio: 0.09819886503824328
#
# Make: ROCKMILLS MP100 ---- defect ratio: 0.09173396243535069

# %%
boiler_inspections.groupby('Bin Number').count()['Tracking Number'].sort_values(ascending=False)
# Out:
# Bin Number
# 3071219    195
# 1088437    102
# 4112321     80
# 4092120     74
# 3347532     72
# 2116700     65
# 4539231     64
# 1008455     53
# 5009578     52
# 1082174     45
# 2005898     45
# 2097050     44
# 5147163     43
# 3056457     42
# 1089325     42
# 1014497     41
# 1080776     38
# 1014464     36
# 4004351     36
# 3189540     35
# 3014856     35
# 3061080     34
# 5113197     34
# 1048914     33
# 1070992     33
# 1088726     32
# 2051208     32
# 1054368     32
# 2117693     32
# 3062358     31
#           ...
# 2000864      1
# 2000865      1
# 2000866      1
# 3135868      1
# 2000732      1
# 2000731      1
# 3135918      1
# 3136011      1
# 2000602      1
# 3135956      1
# 3135955      1
# 2000606      1
# 3135952      1
# 2000610      1
# 3135946      1
# 2000613      1
# 2000614      1
# 2000643      1
# 2000704      1
# 2000656      1
# 3135917      1
# 2000669      1
# 2000672      1
# 3135912      1
# 3135908      1
# 3135905      1
# 2000684      1
# 3135902      1
# 2000690      1
# 3037511      1
# Name: Tracking Number, Length: 70531, dtype: int64

# %% [markdown]
# ### Bin to boiler features

# %%
def bin_to_boiler(bn):
    """ Returns the most recent boiler information for a given Bin.  None if no records."""
    return boiler_inspections[boiler_inspections['Bin Number'] == bn].sort_values(by='Inspection Date', ascending=False).head(1)

# %%
bin_to_boiler(3071219)
# Out:
#                      Tracking Number         Boiler ID Report Type  \
# 164033  2019-30000103737N0001-168469  30000103737N0001     Initial
#
#        ApplicantFirst Name Applicant Last Name Applicant License Type  \
# 164033               CRAIG             MUELLER                     BB
#
#         Applicant License Number Owner First Name Owner Last Name  \
# 164033                    5029.0            LARRY       MOSKOWITZ
#
#          Boiler Make  ...  Pressure Type Inspection Type Inspection Date  \
# 164033  YORK SHIPLEY  ...  High Pressure        Internal      2019-04-09
#
#        Defects Exist  LFF (45 Days)  LFF (180 Days)  Filing Fee  \
# 164033             0              0               0          30
#
#         Total Amount Paid  Report Status Bin Number
# 164033                 30       Accepted    3071219
#
# [1 rows x 21 columns]

# %%
# TODO: change this to get all relevant boiler features
# boiler_feature_names = ['Pressure Type', 'Boiler Make']

def get_boiler_feature(feature):
    boiler_features = []
    for row in boiler_complaints.iterrows():
        boiler_info = bin_to_boiler(row[1]['BIN'])
        
        boiler_feature = boiler_info[feature].values
#         boiler_features.append(boiler_feature)
        
        if len(boiler_feature) > 0:
            boiler_features.append(boiler_feature[0])
#             print(boiler_feature[0])
    #         print(type(boiler_info))
#             break
        else:
            boiler_features.append(None)
    #         print(len(boiler_features))

#     #     index = boiler_complaints.index[boiler_complaints['BIN'] == row[1]['BIN']].values[0]

    return boiler_features

# %%
features['Boiler Make'] = get_boiler_feature('Boiler Make')
features['Pressure Type'] = get_boiler_feature('Pressure Type')
print(features['Boiler Make'].head())
# Out:
# 2082        BURNHAM 1N-4
# 2083                None
# 2084            W.MCLAIN
# 2094    FEDERAL PLW 53HW
# 2883           BEST BLRS
# Name: Boiler Make, dtype: object

# %%
features_with_boiler_features = features.dropna(subset=['Boiler Make'])

print("Percent of complaints with boiler features: {}".format(len(features_with_boiler_features) / len(features)))

print("Percent of complaints with boiler features that result in a violation (balance): {}".format(features_with_boiler_features['Violation'].sum() / len(features_with_boiler_features)))
# Out:
# Percent of complaints with boiler features: 0.6222374507452458
# Percent of complaints with boiler features that result in a violation (balance): 0.5190895741556535

# %% [markdown]
# ### Get number of previous defects

# %%
bin_to_defects = boiler_inspections.groupby('Bin Number').count()['Defects Exist']
defects_column = []
for row in boiler_complaints.iterrows():
    try:
        defects = bin_to_defects[row[1]['BIN']]
    except:
        defects = None
        
    defects_column.append(defects)

# %%
features['Defects'] = defects_column

# %%
features = features.dropna(subset=['Boiler Make'])
features['Boiler Make'] = features['Boiler Make'].astype('category').cat.codes
features['Pressure Type'] = features['Pressure Type'].astype('category').cat.codes
features.head()
# Out:
#       Violation  Complaint Category  Previous Complaints  Previous Violations  \
# 2082          1                   0                    0                    0
# 2084          1                   0                    0                    0
# 2094          0                   0                    0                    0
# 2883          0                   0                    1                    1
# 4670          0                   0                    0                    0
#
#       Violation Ratio  ZIP Code   BIN  Boiler Make  Pressure Type  Defects
# 2082              0.0        64  1883           19              1      1.0
# 2084              0.0        49   108          121              1      1.0
# 2094              0.0        83  3228           40              1      1.0
# 2883              1.0        70  2405           13              1      2.0
# 4670              0.0        83  1441            4              1      5.0

# %%
len(set(features['Boiler Make']))
# Out:
# 129

# %% [markdown]
# # Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
list(features)
# Out:
# ['Violation',
#  'Complaint Category',
#  'Previous Complaints',
#  'Previous Violations',
#  'Violation Ratio',
#  'ZIP Code',
#  'BIN',
#  'Boiler Make',
#  'Pressure Type',
#  'Defects',
#  'Month',
#  'Day']

# %% [markdown]
# ### Create Training and test splits

# %%
y = features['Violation']
X = features[['Violation Ratio', 'ZIP Code', 'Boiler Make', 'Previous Violations', 'Previous Complaints', 'Defects', 'BIN', 'Day']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=None)
print(len(X_train))
print(len(X_test))
# Out:
# 4358
# 6538

# %%
clf = RandomForestClassifier(n_estimators=1000, max_depth=7, random_state=None)
clf.fit(X_train, y_train)

print(list(X))
print(clf.feature_importances_)
print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
feature_importances = pd.DataFrame(clf.feature_importances_, list(X))
feature_importances
# Out:
# ['Violation Ratio', 'ZIP Code', 'Boiler Make', 'Previous Violations', 'Previous Complaints', 'Defects', 'BIN', 'Day']
# [0.17 0.15 0.09 0.1  0.16 0.06 0.19 0.08]
# 0.6826525929325379
# 0.6217497705720404
#                             0
# Violation Ratio      0.174175
# ZIP Code             0.154231
# Boiler Make          0.085331
# Previous Violations  0.102357
# Previous Complaints  0.163046
# Defects              0.055085
# BIN                  0.185840
# Day                  0.079935

# %%
feature_importances.plot(kind='bar', legend=False, colormap='Paired', stacked=True, figsize=(12,6), fontsize=15)

# %% [markdown]
# # Metrics

# %%
# Playing with n_estimators and max_depth improves metrics

# %%
from sklearn.metrics import roc_curve, auc, confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# ### ROC Curve

# %%
y_predict_probs = clf.predict_proba(X_test)
y_preds = clf.predict(X_test)
print(clf.classes_)
print(y_predict_probs)

fpr, tpr, thresholds = roc_curve(y_test, y_predict_probs[:,1])

roc_auc = auc(fpr, tpr)
plt.figure(figsize=(10,10))

plt.plot(fpr, tpr, lw=1, alpha=1,
         label='ROC')

plt.plot([0, 1], [0, 1], linestyle='--', lw=2, color='r',
         label='Chance', alpha=.8)
# Out:
# [0 1]
# [[0.3510322  0.6489678 ]
#  [0.23562707 0.76437293]
#  [0.57529043 0.42470957]
#  ...
#  [0.33335147 0.66664853]
#  [0.51027481 0.48972519]
#  [0.41438313 0.58561687]]

# %%
# Code frome: https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html#sphx-glr-auto-examples-model-selection-plot-confusion-matrix-py
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    print(unique_labels(y_true, y_pred))
#     classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    
    plt.figure(figsize=(15,15))
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
#     thresh = cm.max() / 2.
    thresh = 0.5
    print(thresh)
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax


np.set_printoptions(precision=2)

class_names = ['No Violation', 'Violation']

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test, y_preds, classes=class_names,
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(y_test, y_preds, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')

plt.show()
# Out:
# [0 1]
# Confusion matrix, without normalization
# [[1895 1261]
#  [1185 2197]]
# 0.5
# [0 1]
# Normalized confusion matrix
# [[0.6  0.4 ]
#  [0.35 0.65]]
# 0.5

# %%
# Most confident predictions
sorted(y_predict_probs[:,1])[::-1]
# Out:
# [0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.9199180258136677,
#  0.863815850034262,
#  0.863815850034262,
#  0.863815850034262,
#  0.863815850034262,
#  0.8194921664286796,
#  0.8194921664286796,
#  0.7960267587014839,
#  0.7960267587014839,
#  0.7960267587014839,
#  0.7960267587014839,
#  0.7947543378201092,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7910655828159053,
#  0.7867337230917769,
#  0.7760296877290163,
#  0.7760296877290163,
#  0.7760296877290163,
#  0.7757971251272995,
#  0.7750937296265374,
#  0.7696542925897508,
#  0.768548703378385,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7681241156175485,
#  0.7673304165477497,
#  0.7673304165477497,
#  0.7673304165477497,
#  0.7673304165477497,
#  0.7673304165477497,
#  0.7650846130387279,
#  0.7650846130387279,
#  0.7650846130387279,
#  0.7643729323411279,
#  0.7635543883201692,
#  0.7635543883201692,
#  0.7635543883201692,
#  0.761603946372886,
#  0.7588972162855421,
#  0.7588972162855421,
#  0.7576868980367922,
#  0.7566996758145701,
#  0.7560057062274962,
#  0.7560057062274962,
#  0.7560057062274962,
#  0.7555914055877112,
#  0.7545146273100075,
#  0.7535070278734646,
#  0.7508906505809042,
#  0.7508906505809042,
#  0.7488676326155559,
#  0.7488676326155559,
#  0.7487131144866784,
#  0.7446894688486764,
#  0.7442987307328056,
#  0.7442987307328056,
#  0.7438829389447826,
#  0.7438829389447826,
#  0.7437040596344379,
#  0.7416496352548763,
#  0.7414761097778245,
#  0.7407895356437195,
#  0.7404768830574108,
#  0.7404768830574108,
#  0.7404102559294639,
#  0.7390999683894314,
#  0.7378305275427525,
#  0.7364605913345196,
#  0.7357881459252208,
#  0.7357214051568318,
#  0.7355790486276782,
#  0.7355790486276782,
#  0.7348109935868401,
#  0.734751039539731,
#  0.734127477286746,
#  0.7341194083998638,
#  0.7340594773992813,
#  0.7333627412770345,
#  0.732866838921277,
#  0.731651026913848,
#  0.731651026913848,
#  0.7311873105412493,
#  0.7308006746061962,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306681686104216,
#  0.7306087850652213,
#  0.7303596529473361,
#  0.7303596529473361,
#  0.7294632696291817,
#  0.7293563592185803,
#  0.7293563592185803,
#  0.7290520469529728,
#  0.7290520469529728,
#  0.7290520469529728,
#  0.7289930241000235,
#  0.7288758480668213,
#  0.7285963983960941,
#  0.7283791433343192,
#  0.7283791433343192,
#  0.7283791433343192,
#  0.7283791433343192,
#  0.7279936887633441,
#  0.7279936887633441,
#  0.7279900126345857,
#  0.7277430636725096,
#  0.7273577339047341,
#  0.7273577339047341,
#  0.7273577339047341,
#  0.7273577339047341,
#  0.727341037385709,
#  0.7265438102765429,
#  0.7260604827199233,
#  0.7260604827199233,
#  0.7258579330830807,
#  0.725231916650869,
#  0.7249008544498017,
#  0.7247285663244619,
#  0.7247285663244619,
#  0.7247285663244619,
#  0.7243475319177985,
#  0.7237242906028895,
#  0.7235923636086327,
#  0.7234574937564129,
#  0.7234094654963215,
#  0.7230189125102966,
#  0.7230189125102966,
#  0.7230189125102966,
#  0.7230189125102966,
#  0.7224940136983196,
#  0.7217274139897688,
#  0.7213464901247351,
#  0.7212449249105964,
#  0.7206183096964546,
#  0.7205272989084808,
#  0.7204085411971242,
#  0.7203048529366052,
#  0.7203048529366052,
#  0.7198393608230523,
#  0.7198366927812936,
#  0.7195128518122172,
#  0.7195128518122172,
#  0.7192443187428573,
#  0.7192063549802798,
#  0.7185300936015442,
#  0.7185300936015442,
#  0.7183626603384424,
#  0.7183626603384424,
#  0.7180292624864628,
#  0.7180292624864628,
#  0.7180292624864628,
#  0.7180292624864628,
#  0.7180292624864628,
#  0.7180292624864628,
#  0.7174674455994362,
#  0.7174674455994362,
#  0.7174665503718393,
#  0.7174665503718393,
#  0.7173902554981201,
#  0.717270075111282,
#  0.7169944811282626,
#  0.7169939121150547,
#  0.7165870123585271,
#  0.7165457404530021,
#  0.7160443525504641,
#  0.7159913050320571,
#  0.7158133755861646,
#  0.7157017129564565,
#  0.7156865490662893,
#  0.7155520345147864,
#  0.7155520345147864,
#  0.7155019899348177,
#  0.7154955971332774,
#  0.7154144393420169,
#  0.7147359561378427,
#  0.7141116357990986,
#  0.7141116357990986,
#  0.7141116357990986,
#  0.7141102301038543,
#  0.7140712921248407,
#  0.7140712921248407,
#  0.7139991165195851,
#  0.713869425539097,
#  0.713869425539097,
#  0.7136993871532515,
#  0.7136211486889185,
#  0.7134681282512073,
#  0.7133511799014464,
#  0.7133326800366888,
#  0.7133326800366888,
#  0.7132686181095452,
#  0.7131726114069797,
#  0.7131726114069797,
#  0.7129747251200992,
#  0.7128681116087726,
#  0.7128257616405902,
#  0.7128212962447273,
#  0.7127804623060858,
#  0.7127804623060858,
#  0.7126196044335776,
#  0.7124671349252545,
#  0.7124178960672001,
#  0.7123646257165971,
#  0.7123646257165971,
#  0.71226441743224,
#  0.7122599814338975,
#  0.7122599814338975,
#  0.7122009200011479,
#  0.7122009200011479,
#  0.7116352685493037,
#  0.7114214593767492,
#  0.7114214593767492,
#  0.7113385901696544,
#  0.7112635371307136,
#  0.7112609779279709,
#  0.711214490994064,
#  0.711167286237071,
#  0.7109768740671587,
#  0.7105032565586992,
#  0.7104966325452846,
#  0.7100643050541995,
#  0.7100643050541995,
#  0.7099278712744571,
#  0.7095435045564922,
#  0.7095435045564922,
#  0.7094948215419028,
#  0.7094622871290527,
#  0.7094518329576822,
#  0.7094518329576822,
#  0.7094134714204461,
#  0.7094134714204461,
#  0.7093725742630246,
#  0.7093030503787998,
#  0.7092552390660045,
#  0.709167871206253,
#  0.709133069774989,
#  0.7090541441799485,
#  0.7088211349664183,
#  0.7088211349664183,
#  0.7088211349664183,
#  0.7084229075866344,
#  0.7084229075866344,
#  0.7083726340005804,
#  0.7082072278994447,
#  0.7081838164068158,
#  0.7081838164068158,
#  0.7080767201234252,
#  0.7080223960576093,
#  0.7080223960576093,
#  0.7080223960576093,
#  0.7080223960576093,
#  0.7080223960576093,
#  0.7079626068096583,
#  0.7079416339988918,
#  0.7079044182619246,
#  0.7076283266656774,
#  0.7074012467632088,
#  0.7072026103003363,
#  0.7070386258458137,
#  0.7069550682835447,
#  0.7067377905463329,
#  0.7064876199084781,
#  0.7064691079101347,
#  0.706330496071801,
#  0.70611626381259,
#  0.7060570089537801,
#  0.7058092039039064,
#  0.7057096760591772,
#  0.7054624550955354,
#  0.705449341725296,
#  0.705449341725296,
#  0.7054173952849117,
#  0.7051154109762384,
#  0.7051142313808578,
#  0.7049912684488936,
#  0.7049185463209068,
#  0.7047756499826621,
#  0.7046042958531558,
#  0.7046018129874134,
#  0.7046018129874134,
#  0.7045881889125427,
#  0.7044329954303981,
#  0.7044290833339552,
#  0.7041331900949702,
#  0.703980822778441,
#  0.7039399318939299,
#  0.7038500854065082,
#  0.7038500854065082,
#  0.7038493263242093,
#  0.7038493263242093,
#  0.7038414723276809,
#  0.7035742851035072,
#  0.7035155807574041,
#  0.7033088909873423,
#  0.7032832443660386,
#  0.7031297912685506,
#  0.7031297912685506,
#  0.7030684670654641,
#  0.7029226671366549,
#  0.7028946631661709,
#  0.7027393778380602,
#  0.7026470030503742,
#  0.7026470030503742,
#  0.7025359612329236,
#  0.7024585614200295,
#  0.7024585614200295,
#  0.7024585614200295,
#  0.7022658359462352,
#  0.7022658359462352,
#  0.7022658359462352,
#  0.7022153862635062,
#  0.7020431974871487,
#  0.7020267098212706,
#  0.7018132603571737,
#  0.7018132603571737,
#  0.7016450692247198,
#  0.70156707188159,
#  0.7015425812315215,
#  0.7015425812315215,
#  0.7015387456694427,
#  0.7013629696845317,
#  0.7013629696845317,
#  0.7013313844356253,
#  0.7013313844356253,
#  0.7012879759685705,
#  0.7012879759685705,
#  0.7012817960478589,
#  0.7011594573581542,
#  0.7011594573581542,
#  0.7010692551573197,
#  0.7010681394763452,
#  0.7010310312445549,
#  0.7009939968705454,
#  0.700851200156584,
#  0.7008282962023499,
#  0.7007334781928918,
#  0.7007334781928918,
#  0.7007334781928918,
#  0.700046266625313,
#  0.7000462078659118,
#  0.7000462078659118,
#  0.70003070727569,
#  0.6996370382086939,
#  0.6996162654414005,
#  0.6992861429572599,
#  0.6991723066442411,
#  0.6990628134500038,
#  0.6987120113085646,
#  0.6986545306760904,
#  0.6986456030314266,
#  0.6985413217320141,
#  0.6984132438128196,
#  0.6984105017874175,
#  0.6984044291713489,
#  0.6983839855601915,
#  0.6983839855601915,
#  0.6982884149633505,
#  0.6979491165094721,
#  0.6979491165094721,
#  0.6978877304959799,
#  0.697865567046426,
#  0.6975284228118382,
#  0.6974819738749396,
#  0.697375202079566,
#  0.6973678874335425,
#  0.6973619915300172,
#  0.6973619915300172,
#  0.6973619915300172,
#  0.6973619915300172,
#  0.6973455923227417,
#  0.69732478344002,
#  0.6972390806724726,
#  0.6972390806724726,
#  0.6970915863198777,
#  0.6970142908160222,
#  0.6967889967333974,
#  0.6967506929122217,
#  0.6965919709923919,
#  0.6965867973417372,
#  0.6965197647347792,
#  0.6965068631498528,
#  0.6964879664181332,
#  0.6964721869341903,
#  0.6963539381973799,
#  0.6963136100224115,
#  0.6962023821289259,
#  0.6962023821289259,
#  0.6961977901174461,
#  0.6961977901174461,
#  0.6961977901174461,
#  0.6959606909127449,
#  0.6959573086083096,
#  0.6959429841810171,
#  0.6957517671052361,
#  0.6956974176464014,
#  0.6956542523201492,
#  0.6955822079654135,
#  0.6955803492871767,
#  0.6955803492871767,
#  0.6954557218389561,
#  0.6953894540958537,
#  0.6950659125795587,
#  0.6950266973361551,
#  0.6949423684291763,
#  0.6948973620816686,
#  0.6947022515905336,
#  0.6946857006363137,
#  0.694673015534601,
#  0.694661376038989,
#  0.694315111184977,
#  0.6941963761131005,
#  0.6941883814730659,
#  0.6939493657094623,
#  0.6939349792545705,
#  0.6939134280306988,
#  0.6939079339481031,
#  0.6938550532626834,
#  0.6938097608034984,
#  0.6937933210750598,
#  0.693742811087665,
#  0.6936393206063928,
#  0.6936393206063928,
#  0.6935479839055521,
#  0.6933951207149222,
#  0.6933930904767245,
#  0.6933774921298438,
#  0.6933587416740775,
#  0.6926469095397287,
#  0.6926020758361587,
#  0.692519423183334,
#  0.692519423183334,
#  0.6925178557263553,
#  0.6923288645144102,
#  0.6923288645144102,
#  0.6920470253593239,
#  0.6918478160738926,
#  0.6918290566943927,
#  0.691735120632487,
#  0.6917283515158189,
#  0.6916576103938878,
#  0.6910892651255877,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6909073739735361,
#  0.6908914999629571,
#  0.6908741780214361,
#  0.6908619677519464,
#  0.6907561296534808,
#  0.690752140259208,
#  0.6907249715115087,
#  0.6904057842524157,
#  0.6904057842524157,
#  0.6902398994433623,
#  0.6901908318117775,
#  0.6901908318117775,
#  0.6901908318117775,
#  0.6901906136905047,
#  0.6901398850672029,
#  0.6900927302349157,
#  0.6900927302349157,
#  0.6900927302349157,
#  0.6899944213871357,
#  0.6899927548887007,
#  0.6898642744691582,
#  0.6898642744691582,
#  0.689763144028,
#  0.689763144028,
#  0.6897258242203811,
#  0.6897255583603432,
#  0.6895250470650643,
#  0.6894533719693757,
#  0.6891523473641985,
#  0.6890873792556629,
#  0.6890873792556629,
#  0.6890873792556629,
#  0.6890873792556629,
#  0.6889850755675333,
#  0.6889414198091952,
#  0.6887876139800564,
#  0.6886438713335888,
#  0.6886052951017946,
#  0.6886052951017946,
#  0.6884478897621774,
#  0.6884478401213643,
#  0.6883171667104192,
#  0.6882462828785322,
#  0.6882373957872776,
#  0.6881563494752826,
#  0.6881471742304331,
#  0.6881404513430709,
#  0.6881073964093282,
#  0.6880944521813247,
#  0.6880737227565275,
#  0.6880737227565275,
#  0.6880737227565275,
#  0.6880507298681575,
#  0.6879749089470404,
#  0.6879749089470404,
#  0.6879739489227518,
#  0.6879651987144041,
#  0.6879469749180336,
#  0.6879469749180336,
#  0.6879469749180336,
#  0.687862296005649,
#  0.687862296005649,
#  0.687862296005649,
#  0.6878375112698677,
#  0.6878280980550361,
#  0.6877462458362017,
#  0.6877462458362017,
#  0.6875937065678766,
#  0.687571279922669,
#  0.687571279922669,
#  0.687571279922669,
#  0.6872500573431481,
#  0.6872215077042226,
#  0.6872215077042226,
#  0.6871999529968786,
#  0.6870115626044827,
#  0.6869367510518397,
#  0.6869126138227979,
#  0.6869034177263545,
#  0.6868687026334358,
#  0.6866834373605902,
#  0.6866440294308215,
#  0.686635973875894,
#  0.6866355819870504,
#  0.6862543666483181,
#  0.6862543666483181,
#  0.6857452044644955,
#  0.6856404467110524,
#  0.6856404467110524,
#  0.6856226799431,
#  0.6856004359657938,
#  0.6855594061558448,
#  0.6854105491964978,
#  0.6853343223152939,
#  0.6851080104775547,
#  0.6849869433542339,
#  0.6849869433542339,
#  0.6849869433542339,
#  0.6849869433542339,
#  0.6849869433542339,
#  0.6849514337795335,
#  0.6849079440491644,
#  0.6847649594353923,
#  0.6846404467110524,
#  0.6846227239530643,
#  0.6845045940990275,
#  0.6842881595398896,
#  0.6842881595398896,
#  0.6842881595398896,
#  0.6841036821739584,
#  0.6841000043418073,
#  0.6840102181703611,
#  0.6839932086995326,
#  0.6839750258435481,
#  0.6839626186404202,
#  0.683872294174502,
#  0.683872294174502,
#  0.683872294174502,
#  0.6838717517383796,
#  0.6838717517383796,
#  0.6838717517383796,
#  0.6838717517383796,
#  0.6837270749624026,
#  0.6837270749624026,
#  0.6837270749624026,
#  0.6836669510281309,
#  0.6836081104824083,
#  0.6836017926570198,
#  0.6835563728076492,
#  0.6835563728076492,
#  0.6834623409022509,
#  0.683415572481198,
#  0.6832214628487331,
#  0.6829895153125464,
#  0.6828122261594503,
#  0.6827851706285331,
#  0.6825342410006139,
#  0.6825342410006139,
#  0.6824620706747838,
#  0.6824620706747838,
#  0.6823403398480393,
#  0.682287257078878,
#  0.6822030236283427,
#  0.6821643043363712,
#  0.6821194729541143,
#  0.6820127523404353,
#  0.6819862187232414,
#  0.6819332843113752,
#  0.6819332843113752,
#  0.6818819437159833,
#  0.6818388257324749,
#  0.6817844387125297,
#  0.6816257281388935,
#  0.6815799504465907,
#  0.6815392185192188,
#  0.6813825236497849,
#  0.6811507984866394,
#  0.6811054470805217,
#  0.6811054470805217,
#  0.6810519167951684,
#  0.6809595214888418,
#  0.6807896413054082,
#  0.6807571033142582,
#  0.680729657901822,
#  0.680729657901822,
#  0.680729657901822,
#  0.6807055572481844,
#  0.6804778540010256,
#  0.6804317507844995,
#  0.6803982601298768,
#  0.6802454044738112,
#  0.6802454044738112,
#  0.6801906512338558,
#  0.6801532931845706,
#  0.6801360433278252,
#  0.6801360433278252,
#  0.6801176929344879,
#  0.6800617516808645,
#  0.6800617516808645,
#  0.6800089136804813,
#  0.6799973739229314,
#  0.6799732269096772,
#  0.6798854338056289,
#  0.6797569998330447,
#  0.679655054762536,
#  0.6795110782210464,
#  0.6794781295571731,
#  0.6794781295571731,
#  0.679386470970325,
#  0.679363500821557,
#  0.6792811134396033,
#  0.6792605258764528,
#  0.6792387657529269,
#  0.6792178341682331,
#  0.6792178341682331,
#  0.6791526913142467,
#  0.6791526913142467,
#  0.6790486624854863,
#  0.6789626939128591,
#  0.6789112269551564,
#  0.6789054004958199,
#  0.678722677032719,
#  0.6786355461475251,
#  0.6786037925500922,
#  0.6786037925500922,
#  0.6785491123961251,
#  0.678459903824357,
#  0.6784560272733944,
#  0.6784560272733944,
#  0.6784163402350883,
#  0.6784163402350883,
#  0.6784163402350883,
#  0.6783708214283077,
#  0.6782847071433674,
#  0.6782818584861527,
#  0.6782632005110926,
#  0.6782632005110926,
#  0.6782234337974306,
#  0.6782234337974306,
#  0.6782234337974306,
#  0.6782234337974306,
#  0.6779819520609265,
#  0.6779819520609265,
#  0.6779819520609265,
#  0.6779037333366912,
#  0.6779037333366912,
#  0.6779037333366912,
#  0.6779037333366912,
#  0.6778824150349004,
#  0.6778787597128635,
#  0.6778787597128635,
#  0.6778787597128635,
#  0.6778787597128635,
#  0.6778787597128635,
#  0.6778084194421758,
#  0.677743321936189,
#  0.6776946385036696,
#  0.6776529577845076,
#  0.6775881063563578,
#  0.6775662464896974,
#  0.6774813082758154,
#  0.6773826565933456,
#  0.6773826565933456,
#  0.6772333435610732,
#  0.6772097425858322,
#  0.6772097425858322,
#  0.6771470067815554,
#  0.6771470067815554,
#  0.6771470067815554,
#  0.6771336488486356,
#  0.6771101344675748,
#  0.6771101344675748,
#  0.6769145369626777,
#  0.6768690250985806,
#  0.6768690250985806,
#  0.6768690250985806,
#  0.6766194176912691,
#  0.6765614023700229,
#  0.6765614023700229,
#  0.6764836217143649,
#  0.6764806360272531,
#  0.6762097672740591,
#  0.6761587125923716,
#  0.6761077424924161,
#  0.6761077424924161,
#  0.6760026662455455,
#  0.6758944923568231,
#  0.67578134525275,
#  0.6757119987738807,
#  0.6757119987738807,
#  0.6757119987738807,
#  0.6757119987738807,
#  0.6757119987738807,
#  0.6756324996539045,
#  0.675586653152717,
#  0.6754061310505587,
#  0.6753028505538928,
#  0.6752733133475415,
#  0.6752691085762034,
#  0.6752588329031587,
#  0.6752588329031587,
#  0.6751731138174487,
#  0.6750044358298447,
#  0.6747486088342455,
#  0.674683416614384,
#  0.674683416614384,
#  0.6746323405355069,
#  0.6746323405355069,
#  0.6746323405355069,
#  0.6746289724890527,
#  0.6746289724890527,
#  0.6746289724890527,
#  0.674512223827229,
#  0.6743544557148774,
#  0.6743544557148774,
#  0.6743544557148774,
#  0.6742898497493638,
#  0.6742397459777235,
#  0.6742397459777235,
#  0.6742397459777235,
#  0.6742378171794696,
#  0.6742378171794696,
#  0.6742296583993866,
#  0.6742296583993866,
#  0.6742296583993866,
#  0.6741710479128978,
#  0.6740924229525581,
#  0.6740832905998868,
#  0.6740218537277326,
#  0.673875493381398,
#  0.6737512907821502,
#  0.6736437620579263,
#  0.6736437620579263,
#  0.6735729557456864,
#  0.6735729557456864,
#  0.6735431193874757,
#  0.6735431193874757,
#  0.6735016519351853,
#  0.6734895732547811,
#  0.6734895732547811,
#  0.6734233672853863,
#  0.6733627685381204,
#  0.6733627685381204,
#  0.6733511473669956,
#  0.6733511473669956,
#  0.6733455338645921,
#  0.6732589362987206,
#  0.6732279704850804,
#  0.6732279704850804,
#  0.6730564185400331,
#  0.6729912636250888,
#  0.6729227455051185,
#  0.6729227455051185,
#  0.6729227455051185,
#  0.6729227455051185,
#  0.6729227455051185,
#  0.6728399002156982,
#  0.6728399002156982,
#  0.6728399002156982,
#  0.6725554154226528,
#  0.6724991332463075,
#  0.6722581133093898,
#  0.6722581133093898,
#  0.6722581133093898,
#  0.6721714889996931,
#  0.6720874726377173,
#  0.6720623706260238,
#  0.6719923283251368,
#  0.6719913087579903,
#  0.671987297448745,
#  0.671987297448745,
#  0.671987297448745,
#  0.6719483940401657,
#  0.6719401414876561,
#  0.6718426923456307,
#  0.6718254691455652,
#  0.6718108363123,
#  0.6717812234712942,
#  0.6717259719571007,
#  0.6716762591493479,
#  0.6716407066235407,
#  0.6713767527492825,
#  0.6713291165557862,
#  0.6713291165557862,
#  0.6711683226529818,
#  0.671110848350215,
#  0.671110848350215,
#  0.6709356009790592,
#  0.6709356009790592,
#  0.6708694248359902,
#  0.6708694248359902,
#  0.6708629563064885,
#  0.6708629563064885,
#  0.6708629563064885,
#  0.6707838656337852,
#  0.6706883410635334,
#  0.6706759414578037,
#  0.6706216011995266,
#  0.6705980002210348,
#  0.6704912810504764,
#  0.6704912810504764,
#  0.6704912810504764,
#  0.6704912810504764,
#  0.670440065866376,
#  0.6703516778614718,
#  0.6701454354404401,
#  0.6701454354404401,
#  0.6701454354404401,
#  0.6700900838086944,
#  0.6700765170204361,
#  0.6700765170204361,
#  0.6700695368538102,
#  0.6700669941972297,
#  0.6699925342017636,
#  0.6698695426775261,
#  0.6698695426775261,
#  0.6698517947676921,
#  0.6697959438383612,
#  0.6697904795827042,
#  0.6697816462103332,
#  0.6697697198213846,
#  0.6697661785266467,
#  0.6695645599075003,
#  0.6694851939339437,
#  0.6694851939339437,
#  0.6694851939339437,
#  0.6694084681577992,
#  0.6689673279519339,
#  0.6689188139601641,
#  0.6688325008054659,
#  0.6688325008054659,
#  0.668801882318814,
#  0.668801882318814,
#  0.6687729355085315,
#  0.6686420857341271,
#  0.6686420857341271,
#  0.6686349220390329,
#  0.6686349220390329,
#  0.6686267481804002,
#  0.6685927576260146,
#  0.6685362250877177,
#  0.6684997192518675,
#  0.6684997192518675,
#  0.6684997192518675,
#  0.6684086106846642,
#  0.6684086106846642,
#  0.6683978802528185,
#  0.6683145413367261,
#  0.6682692526336784,
#  0.6682525690734,
#  0.6682525690734,
#  0.6680993341240632,
#  0.6680853514621306,
#  0.6680503649709747,
#  0.6677471932949712,
#  0.6677146291706163,
#  0.6677146291706163,
#  0.6676448551520275,
#  0.6675667127485435,
#  0.6675388849135958,
#  0.6674599961197121,
#  0.6674520875249945,
#  0.6674261799338034,
#  0.667420132632869,
#  0.667420132632869,
#  0.667420132632869,
#  0.66736890747453,
#  0.6673487192997904,
#  0.6673243039143215,
#  0.6671393183838736,
#  0.6670455516428665,
#  0.6669185305944288,
#  0.6668404519746409,
#  0.6668386270607877,
#  0.6668308585640573,
#  0.6667233170502327,
#  0.6666485297886489,
#  0.6666485297886489,
#  0.6666364563858136,
#  0.6666364563858136,
#  0.6666364563858136,
#  0.6666364563858136,
#  0.666617068095958,
#  0.666617068095958,
#  0.6665200015615658,
#  0.6665200015615658,
#  0.6665200015615658,
#  0.6664374657054832,
#  0.6663851699380045,
#  0.6663851699380045,
#  0.6663835011786232,
#  0.6663220187949173,
#  0.6661192783633766,
#  0.6660866361870356,
#  0.6659976655679217,
#  0.665968750106207,
#  0.6657999266024053,
#  0.6656349247787698,
#  0.665632009492243,
#  0.6656079108739406,
#  0.6656079108739406,
#  0.6655603989781539,
#  0.665402537870468,
#  0.665372808702864,
#  0.665371209122777,
#  0.6652264779232835,
#  0.665213931736181,
#  0.6651825454572862,
#  0.6651825454572862,
#  0.6651238761637625,
#  0.6651086560693036,
#  0.6651086560693036,
#  0.665099360132517,
#  0.6648917853019253,
#  0.6645445711666325,
#  0.6642687739656316,
#  0.6638954323355968,
#  0.6638954323355968,
#  0.6637474379200142,
#  0.6636600463346077,
#  0.6636600463346077,
#  0.6636505291231972,
#  0.6635862017956965,
#  0.6635862017956965,
#  0.6635461015025553,
#  0.6635461015025553,
#  0.6634665935001705,
#  0.6634548029242112,
#  0.662832012209219,
#  0.6628124068023206,
#  0.6626516312220834,
#  0.6626516312220834,
#  0.6626085776383451,
#  0.6624266798079249,
#  0.6624113414924251,
#  0.6622659695837334,
#  0.6621311497566973,
#  0.6620971880566471,
#  0.6620706952788231,
#  0.6620706952788231,
#  0.6619919092990484,
#  ...]
